# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
questURL = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest = requests.get(questURL).json()
Quest
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:27 00:16:31.250',
#   'Expression': 'covid 19',
#   'NStudiesAvail': 346890,
#   'NStudiesFound': 2893,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04395924'],
#     'BriefTitle': ['Maternal-foetal Transmission of SARS-Cov-2'],
#     'StatusVerifiedDate': ['June 2020'],
#     'CompletionDate': ['May 2021'],
#     'OrgFullName': ["Centre Hospitalier Régional d'Orléans"],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['Pregnancy',
#      'RT-PCR-COVID-19',
#      'SARS-CoV 2 serologies',
#      'Placenta',
#      'Blood cord',
#      'Amniotic fluid'],
#     'LocationCity': ['Orléans'],
#     'LocationCountry': ['France'],
#     'EnrollmentCount': ['50'],
#     'StdAge': ['Adult'],
#     'Gender': ['Female']}]}}

# %%
limit1 = Quest['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit1
# Out:
# 2893

# %%
tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   
tempL1 = requests.get(tempURL1).json()

tempURL2 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk=2000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

tempURL3 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=2001\
           &max_rnk={limit1}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL3 = requests.get(tempURL3).json()

Q1_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q1_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']
Q1_tempL3 = tempL3['StudyFieldsResponse']['StudyFields']

# %%
Q1_tempDF1 = pd.DataFrame(Q1_tempL1)
Q1_tempDF2 = pd.DataFrame(Q1_tempL2)
Q1_tempDF3 = pd.DataFrame(Q1_tempL3)

# %%
def change_remove45(df):
    df = df.astype(str)
    df["NCTId"] = df["NCTId"].str.lstrip("['")
    df["NCTId"] = df["NCTId"].str.rstrip("']")
    df["BriefTitle"] = df["BriefTitle"].str.lstrip("['")
    df["BriefTitle"] = df["BriefTitle"].str.rstrip("']")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.lstrip("['")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.rstrip("']")
    df["CompletionDate"] = df["CompletionDate"].str.lstrip("['")
    df["CompletionDate"] = df["CompletionDate"].str.rstrip("']")
    df["OrgFullName"] = df["OrgFullName"].str.lstrip("['")
    df["OrgFullName"] = df["OrgFullName"].str.rstrip("']")
    df["OrgClass"] = df["OrgClass"].str.lstrip("['")
    df["OrgClass"] = df["OrgClass"].str.rstrip("']")
    df["Keyword"] = df["Keyword"].str.lstrip("['")
    df["Keyword"] = df["Keyword"].str.rstrip("']")
    df["LocationCity"] = df["LocationCity"].str.lstrip("['")
    df["LocationCity"] = df["LocationCity"].str.rstrip("']")
    df["LocationCountry"] = df["LocationCountry"].str.lstrip("['")
    df["LocationCountry"] = df["LocationCountry"].str.rstrip("']")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.lstrip("['")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.rstrip("']")
    df["StdAge"] = df["StdAge"].str.lstrip("['")
    df["StdAge"] = df["StdAge"].str.rstrip("']")
    df["Gender"] = df["Gender"].str.lstrip("['")
    df["Gender"] = df["Gender"].str.rstrip("']")
    df["LocationFacility"] = df["LocationFacility"].str.lstrip("['")
    df["LocationFacility"] = df["LocationFacility"].str.rstrip("']")
    df["StartDate"] = df["StartDate"].str.lstrip("['")
    df["StartDate"] = df["StartDate"].str.rstrip("']")
    df["LocationStatus"] = df["LocationStatus"].str.lstrip("['")
    df["LocationStatus"] = df["LocationStatus"].str.rstrip("']")
    df["NCTId"] = df["NCTId"].str.replace("'","")
    df["BriefTitle"] = df["BriefTitle"].str.replace("'","")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.replace("'","")
    df["CompletionDate"] = df["CompletionDate"].str.replace("'","")
    df["OrgFullName"] = df["OrgFullName"].str.replace("'","")
    df["OrgClass"] = df["OrgClass"].str.replace("'","")
    df["Keyword"] = df["Keyword"].str.replace("'","")
    df["LocationCity"] = df["LocationCity"].str.replace("'","")
    df["LocationCountry"] = df["LocationCountry"].str.replace("'","")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.replace("'","")
    df["StdAge"] = df["StdAge"].str.replace("'","")
    df["Gender"] = df["Gender"].str.replace("'","")
    df["StartDate"] = df["StartDate"].str.replace("'","")
    df["LocationFacility"] = df["LocationFacility"].str.replace("'","")
    df["LocationFacility"] = df["LocationStatus"].str.replace("'","")
    df["EnrollmentCount"] = pd.to_numeric(df["EnrollmentCount"])
    return df

# %%
clean_Q1_tempDF3 = change_remove45(Q1_tempDF3)
clean_Q1_tempDF3
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    2001  NCT04343651  Study to Evaluate the Efficacy and Safety of L...
# 1    2002  NCT04485169  Therapeutic Plasma Exchange (TPE) for Covid-19...
# 2    2003  NCT04433949  Best Supportive Care With or Without Low Dose ...
# 3    2004  NCT04334512  A Study of Quintuple Therapy to Treat COVID-19...
# 4    2005  NCT04364737  Convalescent Plasma to Limit COVID-19 Complica...
# ..    ...          ...                                                ...
# 888  2889  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 889  2890  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 890  2891  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 891  2892  NCT03922334                        Navigating New Motherhood 2
# 892  2893  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#     StatusVerifiedDate         StartDate     CompletionDate  \
# 0            June 2020     April 1, 2020      April 4, 2021
# 1            July 2020     April 1, 2020      June 30, 2020
# 2            June 2020     June 12, 2020       May 30, 2022
# 3            July 2020     June 22, 2020     September 2021
# 4            June 2020    April 17, 2020     April 30, 2023
# ..                 ...               ...                ...
# 888          June 2020    March 25, 2019      April 8, 2022
# 889           May 2020      May 20, 2019      February 2022
# 890          June 2020     March 1, 2020      June 30, 2023
# 891          June 2020  January 21, 2020      December 2024
# 892          June 2020   August 31, 2020  November 30, 2022
#
#                              OrgFullName  OrgClass  \
# 0                          CytoDyn, Inc.  INDUSTRY
# 1                                 UNICEF     OTHER
# 2                       Emory University     OTHER
# 3                           ProgenaBiome     OTHER
# 4                     NYU Langone Health     OTHER
# ..                                   ...       ...
# 888             University of Pittsburgh     OTHER
# 889    Spaulding Rehabilitation Hospital     OTHER
# 890  University of Alabama at Birmingham     OTHER
# 891              Northwestern University     OTHER
# 892              University of Cambridge     OTHER
#
#                                                Keyword  \
# 0                                             COVID-19
# 1    Therapeutic Plasma exchange, Cytokine release ...
# 2    Radiotherapy, COVID-19, low dose radiotherapy,...
# 3
# 4
# ..                                                 ...
# 888
# 889  Home cooking, Telemedicine, Nutrition, Health ...
# 890                      Adolescents, Zambia, Football
# 891
# 892  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                                       LocationFacility  \
# 0    Recruiting, Recruiting, Recruiting, Recruiting...
# 1
# 2                                           Recruiting
# 3                                           Recruiting
# 4           Not yet recruiting, Recruiting, Recruiting
# ..                                                 ...
# 888                                         Recruiting
# 889                              Completed, Recruiting
# 890                                         Recruiting
# 891                                         Recruiting
# 892
#
#                                         LocationStatus  \
# 0    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 1
# 2                                           Recruiting
# 3                                           Recruiting
# 4       Not yet recruiting', 'Recruiting', 'Recruiting
# ..                                                 ...
# 888                                         Recruiting
# 889                            Completed', 'Recruiting
# 890                                         Recruiting
# 891                                         Recruiting
# 892
#
#                                           LocationCity  \
# 0    Los Angeles, Palm Springs, Rancho Mirage, New ...
# 1                                           Rawalpindi
# 2                                              Atlanta
# 3                                              Ventura
# 4                           New Haven, Bronx, New York
# ..                                                 ...
# 888                                         Pittsburgh
# 889                             Charlestown, Ramat Gan
# 890                                             Lusaka
# 891                                            Chicago
# 892                                          Cambridge
#
#                                        LocationCountry  EnrollmentCount  \
# 0    United States, United States, United States, U...             75.0
# 1                                             Pakistan            280.0
# 2                                        United States             52.0
# 3                                        United States            600.0
# 4          United States, United States, United States            300.0
# ..                                                 ...              ...
# 888                                      United States            112.0
# 889                              United States, Israel             78.0
# 890                                             Zambia           3200.0
# 891                                      United States            400.0
# 892                                     United Kingdom             44.0
#
#                         StdAge  Gender
# 0           Adult, Older Adult     All
# 1           Adult, Older Adult     All
# 2           Adult, Older Adult     All
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 888         Adult, Older Adult     All
# 889         Adult, Older Adult     All
# 890  Child, Adult, Older Adult  Female
# 891               Child, Adult  Female
# 892         Adult, Older Adult     All
#
# [893 rows x 16 columns]

# %%
clean_Q1_tempDF2 = change_remove45(Q1_tempDF2)
clean_Q1_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0
# 4                                   Saudi Arabia            400.0
# ..                                           ...              ...
# 995                                       France            318.0
# 996                                        Italy             50.0
# 997                                      Denmark             79.0
# 998                                       Mexico             30.0
# 999                                       Brazil            149.0
#
#                  StdAge Gender
# 0    Adult, Older Adult    All
# 1    Adult, Older Adult    All
# 2    Adult, Older Adult    All
# 3    Adult, Older Adult    All
# 4    Adult, Older Adult    All
# ..                  ...    ...
# 995  Adult, Older Adult    All
# 996  Adult, Older Adult    All
# 997  Adult, Older Adult    All
# 998  Adult, Older Adult    All
# 999  Adult, Older Adult    All
#
# [1000 rows x 16 columns]

# %%
clean_Q1_tempDF1 = change_remove45(Q1_tempDF1)
clean_Q1_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1       2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4       5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ..    ...          ...                                                ...
# 995   996  NCT04358042                 PSYCHIATRIC Disorders and Covid-19
# 996   997  NCT04397237  Prevalence and Seroconversion of COVID-19 in A...
# 997   998  NCT04358510                COVID-19 Mortality Prediction Model
# 998   999  NCT04387214  COVID-19 Pandemic and Academic Performance of ...
# 999  1000  NCT04397718  Hormonal Intervention for the Treatment in Vet...
#
#     StatusVerifiedDate       StartDate      CompletionDate  \
# 0            June 2020     May 5, 2020            May 2021
# 1             May 2020  April 15, 2020    October 15, 2020
# 2            July 2020  September 2020           June 2022
# 3            June 2020   March 1, 2020       March 1, 2021
# 4            June 2020    May 15, 2020  September 30, 2020
# ..                 ...             ...                 ...
# 995          July 2020  April 24, 2020     January 1, 2023
# 996           May 2020        May 2020       December 2020
# 997         April 2020   April 1, 2020      April 17, 2020
# 998          June 2020  April 13, 2020        May 31, 2020
# 999          July 2020    July 6, 2020    December 6, 2020
#
#                                 OrgFullName  OrgClass  \
# 0    "Centre Hospitalier Régional dOrléans"     OTHER
# 1              University of Milano Bicocca     OTHER
# 2                   Meharry Medical College     OTHER
# 3              University of Milano Bicocca     OTHER
# 4              University of Milano Bicocca     OTHER
# ..                                      ...       ...
# 995              Nantes University Hospital     OTHER
# 996              Pitié-Salpêtrière Hospital     OTHER
# 997                                 Dascena  INDUSTRY
# 998                 South Valley University     OTHER
# 999   VA Office of Research and Development       FED
#
#                                                Keyword  \
# 0    Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1     Lung injury, sars-covid-2, coronavirus infection
# 2    COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3    Coronavirus, sars-covid-2, coronavirus infecti...
# 4     Coronavirus, sars-covid-2, coronavirus infection
# ..                                                 ...
# 995  Psychiatry, COVID-19, psychological impact, ac...
# 996  COVID-19, Systemic Lupus Erythematosus, "Sjogr...
# 997  machine learning, COVID-19, mortality, predict...
# 998
# 999
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1    Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995                                         Recruiting
# 996
# 997
# 998
# 999     Recruiting, Recruiting, Recruiting, Recruiting
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995                                         Recruiting
# 996
# 997
# 998
# 999  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
#
#                                           LocationCity  \
# 0                                              Orléans
# 1    Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                            Nashville
# 3                                                Monza
# 4                                                Monza
# ..                                                 ...
# 995                                             Nantes
# 996
# 997                                            Oakland
# 998                                               Qinā
# 999      West Los Angeles, Brooklyn, New York, Seattle
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                               France             50.0
# 1    Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                        United States            200.0
# 3                                                Italy            300.0
# 4                                                Italy            500.0
# ..                                                 ...              ...
# 995                                             France            250.0
# 996                                                              3600.0
# 997                                      United States            114.0
# 998                                              Egypt            857.0
# 999  United States, United States, United States, U...            198.0
#
#                         StdAge  Gender
# 0                        Adult  Female
# 1           Adult, Older Adult     All
# 2                        Adult  Female
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 995  Child, Adult, Older Adult     All
# 996         Adult, Older Adult     All
# 997         Adult, Older Adult     All
# 998               Child, Adult     All
# 999         Adult, Older Adult    Male
#
# [1000 rows x 16 columns]

# %%
query = 'coronavirus'
quest2URL = f'http://ClinicalTrials.gov/api/query/study_fields?expr={query}\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest2 = requests.get(quest2URL).json()
Quest2
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:27 00:16:31.250',
#   'Expression': 'coronavirus',
#   'NStudiesAvail': 346890,
#   'NStudiesFound': 1463,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'StartDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationFacility',
#    'LocationStatus',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04279795'],
#     'BriefTitle': ['Detection of 2019 Novel Coronavirus in Multiple Organ System and Its Relationship With Clinical Manifestations'],
#     'StatusVerifiedDate': ['February 2020'],
#     'StartDate': ['January 20, 2020'],
#     'CompletionDate': ['February 28, 2021'],
#     'OrgFullName': ['Third Affiliated Hospital, Sun Yat-Sen University'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['2019 Novel Coronavirus'],
#     'LocationFacility': ['The Third Affiliated Hospital of Sun Yat-sen University'],
#     'LocationStatus': ['Recruiting'],
#     'LocationCity': ['Guangzhou'],
#     'LocationCountry': ['China'],
#     'EnrollmentCount': ['20'],
#     'StdAge': ['Child', 'Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
limit2 = Quest2['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit2
# Out:
# 1463

# %%
tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   

tempL1 = requests.get(tempURL1).json()

tempURL2 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk={limit2}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

Q2_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q2_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']

# %%
Q2_tempDF1 = pd.DataFrame(Q2_tempL1)
Q2_tempDF2 = pd.DataFrame(Q2_tempL2)

# %%
clean_Q2_tempDF1 = change_remove45(Q2_tempDF1)
clean_Q2_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 
italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                        United States            200.0
# 3                                                Italy            300.0
# 4                                                Italy            500.0
# ..                                                 ...              ...
# 995                                             France            250.0
# 996                                                              3600.0
# 997                                      United States            114.0
# 998                                              Egypt            857.0
# 999  United States, United States, United States, U...            198.0
#
#                         StdAge  Gender
# 0                        Adult  Female
# 1           Adult, Older Adult     All
# 2                        Adult  Female
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 995  Child, Adult, Older Adult     All
# 996         Adult, Older Adult     All
# 997         Adult, Older Adult     All
# 998               Child, Adult     All
# 999         Adult, Older Adult    Male
#
# [1000 rows x 16 columns]

# %%
clean_Q2_tempDF2 = change_remove45(Q2_tempDF2)
clean_Q2_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04347538  Impact of Nasal Saline Irrigations on Viral Lo...
# 1    1002  NCT04348500  Clazakizumab (Anti-IL- 6 Monoclonal) Compared ...
# 2    1003  NCT04328493      The Vietnam Chloroquine Treatment on COVID-19
# 3    1004  NCT04438993      The COVID-19 Disease and CARdiac Events Study
# 4    1005  NCT04377802  Safe Return to Regular Clinical Operation Afte...
# ..    ...          ...                                                ...
# 458  1459  NCT04394442            Hydroxychloroquine in COVID-19 Patients
# 459  1460  NCT04357613     IMATINIB IN COVID-19 DISEASE IN AGED PATIENTS.
# 460  1461  NCT04292899  Study to Evaluate the Safety and Antiviral Act...
# 461  1462  NCT04353323             COVID 19-Caregivers IGg Seroconversion
# 462  1463  NCT04359706  Bacterial and Fungal Microbiota of Patients Wi...
#
#     StatusVerifiedDate       StartDate     CompletionDate  \
# 0             May 2020     May 1, 2020          June 2022
# 1            June 2020  April 24, 2020     March 31, 2021
# 2             May 2020   April 7, 2020      April 1, 2022
# 3            June 2020    May 29, 2020      November 2020
# 4             May 2020    May 17, 2020  December 30, 2020
# ..                 ...             ...                ...
# 458           May 2020  March 21, 2020        August 2020
# 459         April 2020     May 1, 2020   December 1, 2020
# 460          July 2020   March 6, 2020      June 30, 2020
# 461         April 2020    May 25, 2020  December 25, 2020
# 462         April 2020      April 2020     September 2020
#
#                                            OrgFullName   OrgClass  \
# 0                 Vanderbilt University Medical Center      OTHER
# 1                          Cedars-Sinai Medical Center      OTHER
# 2    Oxford University Clinical Research Unit, Vietnam      OTHER
# 3                                      NHS Lanarkshire  OTHER_GOV
# 4                King Fahad Specialist Hospital Dammam      OTHER
# ..                                                 ...        ...
# 458                                 Zagazig University  OTHER_GOV
# 459                                Versailles Hospital      OTHER
# 460                                    Gilead Sciences   INDUSTRY
# 461                       University Hospital, Limoges      OTHER
# 462                         University Hospital, Lille      OTHER
#
#                                             Keyword  \
# 0
# 1
# 2                 SARS-CoV-2, COVID-19, chloroquine
# 3    Echocardiogram, Troponin, NT-proBNP, Cytokines
# 4
# ..                                              ...
# 458
# 459
# 460
# 461
# 462
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1                                           Recruiting
# 2    Not yet recruiting, Recruiting, Not yet recrui...
# 3                                           Recruiting
# 4
# ..                                                 ...
# 458                                         Recruiting
# 459
# 460
# 461
# 462
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1                                           Recruiting
# 2    Not yet recruiting', 'Recruiting', 'Not yet re...
# 3                                           Recruiting
# 4
# ..                                                 ...
# 458                                         Recruiting
# 459
# 460
# 461
# 462
#
#                                           LocationCity  \
# 0                                            Nashville
# 1                                          Los Angeles
# 2    Hanoi, Ho Chi Minh City, Ho Chi Minh City, Ho ...
# 3                                              Glasgow
# 4                                               Dammam
# ..                                                 ...
# 458                                              Mecca
# 459                               Bordeaux, Le Chesnay
# 460  Anaheim, Berkeley, Burlingame, Castro Valley, ...
# 461                                            Limoges
# 462
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                        United States             90.0
# 1                                        United States             60.0
# 2          Vietnam, Vietnam, Vietnam, Vietnam, Vietnam            250.0
# 3                                       United Kingdom            100.0
# 4                                         Saudi Arabia            400.0
# ..                                                 ...              ...
# 458                                       Saudi Arabia            200.0
# 459                                     France, France             99.0
# 460  United States, United States, United States, U...           4891.0
# 461                                             France            130.0
# 462                                                                30.0
#
#                         StdAge Gender
# 0           Adult, Older Adult    All
# 1           Adult, Older Adult    All
# 2           Adult, Older Adult    All
# 3           Adult, Older Adult    All
# 4           Adult, Older Adult    All
# ..                         ...    ...
# 458         Adult, Older Adult    All
# 459                Older Adult    All
# 460  Child, Adult, Older Adult    All
# 461         Adult, Older Adult    All
# 462         Adult, Older Adult    All
#
# [463 rows x 16 columns]

# %%
DF_QQ = pd.concat([clean_Q1_tempDF1, clean_Q1_tempDF2, clean_Q1_tempDF3, clean_Q2_tempDF1, clean_Q2_tempDF2], ignore_index=True)
DF_QQ = DF_QQ.drop_duplicates()
DF_QQ
# Out:
#       Rank        NCTId                                         BriefTitle  \
# 0        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2        3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3        4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4        5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ...    ...          ...                                                ...
# 2888  2889  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 2889  2890  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 2890  2891  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 2891  2892  NCT03922334                        Navigating New Motherhood 2
# 2892  2893  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#      StatusVerifiedDate         StartDate      CompletionDate  \
# 0             June 2020       May 5, 2020            May 2021
# 1              May 2020    April 15, 2020    October 15, 2020
# 2             July 2020    September 2020           June 2022
# 3             June 2020     March 1, 2020       March 1, 2021
# 4             June 2020      May 15, 2020  September 30, 2020
# ...                 ...               ...                 ...
# 2888          June 2020    March 25, 2019       April 8, 2022
# 2889           May 2020      May 20, 2019       February 2022
# 2890          June 2020     March 1, 2020       June 30, 2023
# 2891          June 2020  January 21, 2020       December 2024
# 2892          June 2020   August 31, 2020   November 30, 2022
#
#                                  OrgFullName OrgClass  \
# 0     "Centre Hospitalier Régional dOrléans"    OTHER
# 1               University of Milano Bicocca    OTHER
# 2                    Meharry Medical College    OTHER
# 3               University of Milano Bicocca    OTHER
# 4               University of Milano Bicocca    OTHER
# ...                                      ...      ...
# 2888                University of Pittsburgh    OTHER
# 2889       Spaulding Rehabilitation Hospital    OTHER
# 2890     University of Alabama at Birmingham    OTHER
# 2891                 Northwestern University    OTHER
# 2892                 University of Cambridge    OTHER
#
#                                                 Keyword  \
# 0     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1      Lung injury, sars-covid-2, coronavirus infection
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Coronavirus, sars-covid-2, coronavirus infecti...
# 4      Coronavirus, sars-covid-2, coronavirus infection
# ...                                                 ...
# 2888
# 2889  Home cooking, Telemedicine, Nutrition, Health ...
# 2890                      Adolescents, Zambia, Football
# 2891
# 2892  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                                        LocationFacility  \
# 0                                            Recruiting
# 1     Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 2888                                         Recruiting
# 2889                              Completed, Recruiting
# 2890                                         Recruiting
# 2891                                         Recruiting
# 2892
#
#                                          LocationStatus  \
# 0                                            Recruiting
# 1     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 2888                                         Recruiting
# 2889                            Completed', 'Recruiting
# 2890                                         Recruiting
# 2891                                         Recruiting
# 2892
#
#                                            LocationCity  \
# 0                                               Orléans
# 1     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                             Nashville
# 3                                                 Monza
# 4                                                 Monza
# ...                                                 ...
# 2888                                         Pittsburgh
# 2889                             Charlestown, Ramat Gan
# 2890                                             Lusaka
# 2891                                            Chicago
# 2892                                          Cambridge
#
#                                         LocationCountry  EnrollmentCount  \
# 0                                                France             50.0
# 1     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                         United States            200.0
# 3                                                 Italy            300.0
# 4                                                 Italy            500.0
# ...                                                 ...              ...
# 2888                                      United States            112.0
# 2889                              United States, Israel             78.0
# 2890                                             Zambia           3200.0
# 2891                                      United States            400.0
# 2892                                     United Kingdom             44.0
#
#                          StdAge  Gender
# 0                         Adult  Female
# 1            Adult, Older Adult     All
# 2                         Adult  Female
# 3            Adult, Older Adult     All
# 4            Adult, Older Adult     All
# ...                         ...     ...
# 2888         Adult, Older Adult     All
# 2889         Adult, Older Adult     All
# 2890  Child, Adult, Older Adult  Female
# 2891               Child, Adult  Female
# 2892         Adult, Older Adult     All
#
# [2893 rows x 16 columns]

# %%
dupe_dupe = DF_QQ.pivot_table(index=['NCTId'], aggfunc='size')
print (dupe_dupe)
# Out:
# NCTId
# NCT01306084    1
# NCT02517489    1
# NCT02656381    1
# NCT02735707    1
# NCT02765191    1
#               ..
# NCT04487951    1
# NCT04487964    1
# NCT04487977    1
# NCT04487990    1
# NCT04488081    1
# Length: 2893, dtype: int64

# %%
df_final = DF_QQ.drop_duplicates(subset='NCTId', keep="first")
df_final
# Out:
#       Rank        NCTId                                         BriefTitle  \
# 0        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2        3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3        4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4        5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ...    ...          ...                                                ...
# 2888  2889  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 2889  2890  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 2890  2891  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 2891  2892  NCT03922334                        Navigating New Motherhood 2
# 2892  2893  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#      StatusVerifiedDate         StartDate      CompletionDate  \
# 0             June 2020       May 5, 2020            May 2021
# 1              May 2020    April 15, 2020    October 15, 2020
# 2             July 2020    September 2020           June 2022
# 3             June 2020     March 1, 2020       March 1, 2021
# 4             June 2020      May 15, 2020  September 30, 2020
# ...                 ...               ...                 ...
# 2888          June 2020    March 25, 2019       April 8, 2022
# 2889           May 2020      May 20, 2019       February 2022
# 2890          June 2020     March 1, 2020       June 30, 2023
# 2891          June 2020  January 21, 2020       December 2024
# 2892          June 2020   August 31, 2020   November 30, 2022
#
#                                  OrgFullName OrgClass  \
# 0     "Centre Hospitalier Régional dOrléans"    OTHER
# 1               University of Milano Bicocca    OTHER
# 2                    Meharry Medical College    OTHER
# 3               University of Milano Bicocca    OTHER
# 4               University of Milano Bicocca    OTHER
# ...                                      ...      ...
# 2888                University of Pittsburgh    OTHER
# 2889       Spaulding Rehabilitation Hospital    OTHER
# 2890     University of Alabama at Birmingham    OTHER
# 2891                 Northwestern University    OTHER
# 2892                 University of Cambridge    OTHER
#
#                                                 Keyword  \
# 0     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1      Lung injury, sars-covid-2, coronavirus infection
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Coronavirus, sars-covid-2, coronavirus infecti...
# 4      Coronavirus, sars-covid-2, coronavirus infection
# ...                                                 ...
# 2888
# 2889  Home cooking, Telemedicine, Nutrition, Health ...
# 2890                      Adolescents, Zambia, Football
# 2891
# 2892  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                                        LocationFacility  \
# 0                                            Recruiting
# 1     Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 2888                                         Recruiting
# 2889                              Completed, Recruiting
# 2890                                         Recruiting
# 2891                                         Recruiting
# 2892
#
#                                          LocationStatus  \
# 0                                            Recruiting
# 1     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 2888                                         Recruiting
# 2889                            Completed', 'Recruiting
# 2890                                         Recruiting
# 2891                                         Recruiting
# 2892
#
#                                            LocationCity  \
# 0                                               Orléans
# 1     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                             Nashville
# 3                                                 Monza
# 4                                                 Monza
# ...                                                 ...
# 2888                                         Pittsburgh
# 2889                             Charlestown, Ramat Gan
# 2890                                             Lusaka
# 2891                                            Chicago
# 2892                                          Cambridge
#
#                                         LocationCountry  EnrollmentCount  \
# 0                                                France             50.0
# 1     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                         United States            200.0
# 3                                                 Italy            300.0
# 4                                                 Italy            500.0
# ...                                                 ...              ...
# 2888                                      United States            112.0
# 2889                              United States, Israel             78.0
# 2890                                             Zambia           3200.0
# 2891                                      United States            400.0
# 2892                                     United Kingdom             44.0
#
#                          StdAge  Gender
# 0                         Adult  Female
# 1            Adult, Older Adult     All
# 2                         Adult  Female
# 3            Adult, Older Adult     All
# 4            Adult, Older Adult     All
# ...                         ...     ...
# 2888         Adult, Older Adult     All
# 2889         Adult, Older Adult     All
# 2890  Child, Adult, Older Adult  Female
# 2891               Child, Adult  Female
# 2892         Adult, Older Adult     All
#
# [2893 rows x 16 columns]

# %%
df_final.set_index('NCTId', inplace=True)
df_final
# Out:
#              Rank                                         BriefTitle  \
# NCTId
# NCT04395924     1         Maternal-foetal Transmission of SARS-Cov-2
# NCT04395482     2  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# NCT04180709             44.0         Adult, Older Adult     All      (0, 100]
#
# [2893 rows x 16 columns]

# %%
df_enrollment = df_final.groupby("binned")[["BriefTitle"]].count()

# %%
df_enrollment = df_enrollment.reset_index()
df_enrollment
# Out:
#                  binned  BriefTitle
# 0              (0, 100]        1122
# 1            (100, 250]         568
# 2            (250, 500]         432
# 3           (500, 1000]         293
# 4          (1000, 2500]         194
# 5          (2500, 5000]          97
# 6         (5000, 10000]          55
# 7        (10000, 50000]          51
# 8       (50000, 100000]          12
# 9  (100000, 1000000000]          21

# %%
notnew = newnew.reset_index()
notnew
# Out:
#                  binned  BriefTitle
# 0              (0, 100]        1122
# 1            (100, 250]         568
# 2            (250, 500]         432
# 3           (500, 1000]         293
# 4          (1000, 2500]         194
# 5          (2500, 5000]          97
# 6         (5000, 10000]          55
# 7        (10000, 50000]          51
# 8       (50000, 100000]          12
# 9  (100000, 1000000000]          21

# %%
enrollment_bar = df_enrollment.plot.bar(x='binned', y='BriefTitle', rot=45, legend=False, color="r")
plt.xlabel('Participants per Study')
plt.ylabel('Number of Studies')
plt.title('Number of Studies by Enrollment')
# Out:
# Text(0.5, 1.0, 'Number of Studies by Enrollment')

# %%
df_age = df_final.groupby("StdAge")[["BriefTitle"]].count()
df_age
# Out:
#                            BriefTitle
# StdAge
# Adult                             148
# Adult, Older Adult               2192
# Child                              28
# Child, Adult                       42
# Child, Adult, Older Adult         449
# Older Adult                        34

# %%
df_age = df_age.reset_index()
df_age
# Out:
#                       StdAge  BriefTitle
# 0                      Adult         148
# 1         Adult, Older Adult        2192
# 2                      Child          28
# 3               Child, Adult          42
# 4  Child, Adult, Older Adult         449
# 5                Older Adult          34

# %%
df_age = df_age.sort_values(by=['BriefTitle'])

# %%
age_bar = df_age.plot.barh(x='StdAge', y='BriefTitle', rot=0, legend=False)
plt.xlabel('Number of Studies')
plt.ylabel('Target Age Group(s)')
plt.title('Number of Studies by Target Age Group')
# Out:
# Text(0.5, 1.0, 'Number of Studies by Target Age Group')

# %%
df_gender = df_final.groupby("Gender")[["BriefTitle"]].count()
df_gender
# Out:
#         BriefTitle
# Gender
#                  5
# All           2797
# Female          71
# Male            20

# %%
pie_labels = ["Unknown", "All", "Female", "Male"]
pie_values = [5, 2797, 71, 20]
explode = (.75, 0, 1.5, 3)
color_list = ['#0f7216', '#b2790c', '#ffe9a3',
              '#f9d4d4', '#d35158', '#ea3033']
import squarify
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-167-e5760347b951> in <module>
#       4 color_list = ['#0f7216', '#b2790c', '#ffe9a3',
#       5               '#f9d4d4', '#d35158', '#ea3033']
# ----> 6 import squarify
#
# ModuleNotFoundError: No module named 'squarify'

# %%
plt.figure(figsize=(16,8))
ax3 = plt.subplot(121, aspect='equal')
df_gender.plot(kind='pie', y = 'BriefTitle', ax=ax3, autopct='%1.1f%%', 
 startangle=0, shadow=True, labels=pie_labels, legend = False, fontsize=15, explode=explode)
plt.show()

# %%
plt.rc('font', size=14)
squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=0.7)
plt.axis('off')

plt.show()
