# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
questURL = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest = requests.get(questURL).json()
Quest
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:28 00:13:26.360',
#   'Expression': 'covid 19',
#   'NStudiesAvail': 347033,
#   'NStudiesFound': 2905,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04395924'],
#     'BriefTitle': ['Maternal-foetal Transmission of SARS-Cov-2'],
#     'StatusVerifiedDate': ['June 2020'],
#     'CompletionDate': ['May 2021'],
#     'OrgFullName': ["Centre Hospitalier Régional d'Orléans"],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['Pregnancy',
#      'RT-PCR-COVID-19',
#      'SARS-CoV 2 serologies',
#      'Placenta',
#      'Blood cord',
#      'Amniotic fluid'],
#     'LocationCity': ['Orléans'],
#     'LocationCountry': ['France'],
#     'EnrollmentCount': ['50'],
#     'StdAge': ['Adult'],
#     'Gender': ['Female']}]}}

# %%
limit1 = Quest['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit1
# Out:
# 2905

# %%
tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   
tempL1 = requests.get(tempURL1).json()

tempURL2 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk=2000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

tempURL3 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=2001\
           &max_rnk={limit1}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL3 = requests.get(tempURL3).json()

Q1_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q1_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']
Q1_tempL3 = tempL3['StudyFieldsResponse']['StudyFields']

# %%
Q1_tempDF1 = pd.DataFrame(Q1_tempL1)
Q1_tempDF2 = pd.DataFrame(Q1_tempL2)
Q1_tempDF3 = pd.DataFrame(Q1_tempL3)

# %%
def change_remove45(df):
    df = df.astype(str)
    df["NCTId"] = df["NCTId"].str.lstrip("['")
    df["NCTId"] = df["NCTId"].str.rstrip("']")
    df["BriefTitle"] = df["BriefTitle"].str.lstrip("['")
    df["BriefTitle"] = df["BriefTitle"].str.rstrip("']")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.lstrip("['")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.rstrip("']")
    df["CompletionDate"] = df["CompletionDate"].str.lstrip("['")
    df["CompletionDate"] = df["CompletionDate"].str.rstrip("']")
    df["OrgFullName"] = df["OrgFullName"].str.lstrip("['")
    df["OrgFullName"] = df["OrgFullName"].str.rstrip("']")
    df["OrgClass"] = df["OrgClass"].str.lstrip("['")
    df["OrgClass"] = df["OrgClass"].str.rstrip("']")
    df["Keyword"] = df["Keyword"].str.lstrip("['")
    df["Keyword"] = df["Keyword"].str.rstrip("']")
    df["LocationCity"] = df["LocationCity"].str.lstrip("['")
    df["LocationCity"] = df["LocationCity"].str.rstrip("']")
    df["LocationCountry"] = df["LocationCountry"].str.lstrip("['")
    df["LocationCountry"] = df["LocationCountry"].str.rstrip("']")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.lstrip("['")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.rstrip("']")
    df["StdAge"] = df["StdAge"].str.lstrip("['")
    df["StdAge"] = df["StdAge"].str.rstrip("']")
    df["Gender"] = df["Gender"].str.lstrip("['")
    df["Gender"] = df["Gender"].str.rstrip("']")
    df["LocationFacility"] = df["LocationFacility"].str.lstrip("['")
    df["LocationFacility"] = df["LocationFacility"].str.rstrip("']")
    df["StartDate"] = df["StartDate"].str.lstrip("['")
    df["StartDate"] = df["StartDate"].str.rstrip("']")
    df["LocationStatus"] = df["LocationStatus"].str.lstrip("['")
    df["LocationStatus"] = df["LocationStatus"].str.rstrip("']")
    df["NCTId"] = df["NCTId"].str.replace("'","")
    df["BriefTitle"] = df["BriefTitle"].str.replace("'","")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.replace("'","")
    df["CompletionDate"] = df["CompletionDate"].str.replace("'","")
    df["OrgFullName"] = df["OrgFullName"].str.replace("'","")
    df["OrgClass"] = df["OrgClass"].str.replace("'","")
    df["Keyword"] = df["Keyword"].str.replace("'","")
    df["LocationCity"] = df["LocationCity"].str.replace("'","")
    df["LocationCountry"] = df["LocationCountry"].str.replace("'","")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.replace("'","")
    df["StdAge"] = df["StdAge"].str.replace("'","")
    df["Gender"] = df["Gender"].str.replace("'","")
    df["StartDate"] = df["StartDate"].str.replace("'","")
    df["LocationFacility"] = df["LocationFacility"].str.replace("'","")
    df["LocationFacility"] = df["LocationStatus"].str.replace("'","")
    df["EnrollmentCount"] = pd.to_numeric(df["EnrollmentCount"])
    return df

# %%
clean_Q1_tempDF3 = change_remove45(Q1_tempDF3)
clean_Q1_tempDF3
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    2001  NCT04472728  Testing the Efficacy and Safety of BIO101 for ...
# 1    2002  NCT04350086  Use of Dexmedetomidine in Light to Moderate Se...
# 2    2003  NCT04369469  Efficacy and Safety Study of IV Ravulizumab in...
# 3    2004  NCT04357860  Clinical Trial of Sarilumab in Adults With COV...
# 4    2005  NCT04334148  Healthcare Worker Exposure Response and Outcom...
# ..    ...          ...                                                ...
# 900  2901  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 901  2902  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 902  2903  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 903  2904  NCT03922334                        Navigating New Motherhood 2
# 904  2905  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#     StatusVerifiedDate         StartDate     CompletionDate  \
# 0            July 2020     June 16, 2020     September 2021
# 1           April 2020    April 20, 2020  November 20, 2020
# 2           April 2020      May 11, 2020      February 2021
# 3           April 2020    April 27, 2020      July 27, 2020
# 4            July 2020    April 22, 2020     September 2020
# ..                 ...               ...                ...
# 900          June 2020    March 25, 2019      April 8, 2022
# 901           May 2020      May 20, 2019      February 2022
# 902          June 2020     March 1, 2020      June 30, 2023
# 903          June 2020  January 21, 2020      December 2024
# 904          June 2020   August 31, 2020  November 30, 2022
#
#                                            OrgFullName  OrgClass  \
# 0                                            Biophytis  INDUSTRY
# 1                         University Hospital, Limoges     OTHER
# 2                              Alexion Pharmaceuticals  INDUSTRY
# 3    Maimónides Biomedical Research Institute of Có...     OTHER
# 4                                      Duke University     OTHER
# ..                                                 ...       ...
# 900                           University of Pittsburgh     OTHER
# 901                  Spaulding Rehabilitation Hospital     OTHER
# 902                University of Alabama at Birmingham     OTHER
# 903                            Northwestern University     OTHER
# 904                            University of Cambridge     OTHER
#
#                                                Keyword  \
# 0
# 1    COVID-19, sars-cov-2, infection, respiratory f...
# 2    acute lung injury, acute respiratory distress ...
# 3
# 4    Hydroxychloroquine, Coronavirus Infections, No...
# ..                                                 ...
# 900
# 901  Home cooking, Telemedicine, Nutrition, Health ...
# 902                      Adolescents, Zambia, Football
# 903
# 904  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1
# 2    Recruiting, Recruiting, Recruiting, Recruiting...
# 3
# 4    Recruiting, Recruiting, Recruiting, Recruiting...
# ..                                                 ...
# 900                                         Recruiting
# 901                              Completed, Recruiting
# 902                                         Recruiting
# 903                                         Recruiting
# 904
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1
# 2    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 3
# 4    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# ..                                                 ...
# 900                                         Recruiting
# 901                            Completed', 'Recruiting
# 902                                         Recruiting
# 903                                         Recruiting
# 904
#
#                                           LocationCity  \
# 0                                             Mechelen
# 1                                              Limoges
# 2    Washington, Boston, Detroit, Créteil, Garches,...
# 3                                              Córdoba
# 4    Aurora, Gainesville, Jacksonville, Leesburg, M...
# ..                                                 ...
# 900                                         Pittsburgh
# 901                             Charlestown, Ramat Gan
# 902                                             Lusaka
# 903                                            Chicago
# 904                                          Cambridge
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                              Belgium            310.0
# 1                                               France             10.0
# 2    United States, United States, United States, F...            270.0
# 3                                                Spain            120.0
# 4    United States, United States, United States, U...           2000.0
# ..                                                 ...              ...
# 900                                      United States            112.0
# 901                              United States, Israel             78.0
# 902                                             Zambia           3200.0
# 903                                      United States            400.0
# 904                                     United Kingdom             44.0
#
#                         StdAge  Gender
# 0           Adult, Older Adult     All
# 1           Adult, Older Adult     All
# 2           Adult, Older Adult     All
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 900         Adult, Older Adult     All
# 901         Adult, Older Adult     All
# 902  Child, Adult, Older Adult  Female
# 903               Child, Adult  Female
# 904         Adult, Older Adult     All
#
# [905 rows x 16 columns]

# %%
clean_Q1_tempDF2 = change_remove45(Q1_tempDF2)
clean_Q1_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04407273              STATIN THERAPY AND COVID-19 INFECTION
# 1    1002  NCT04403100  Hydroxychloroquine and Lopinavir/ Ritonavir to...
# 2    1003  NCT04391712  Cold Laser Therapy for COVID-19 Positive Patie...
# 3    1004  NCT04338672  The Impact of the Covid-19 Outbreak on Emergen...
# 4    1005  NCT04431466  A Study to Compare the Efficacy and Safety of ...
# ..    ...          ...                                                ...
# 995  1996  NCT04392713                 Efficacy of Ivermectin in COVID-19
# 996  1997  NCT04424056  A Trial Using ANAKINRA, TOCILIZUMAB Alone or i...
# 997  1998  NCT04484025   SPI-1005 Treatment in Moderate COVID-19 Patients
# 998  1999  NCT04344210  Impact of Tele-interventions During the COVID-...
# 999  2000  NCT04473183  Epidemiologic Assessment of SARS-CoV-2 (COVID-...
#
#     StatusVerifiedDate          StartDate     CompletionDate  \
# 0             May 2020       May 14, 2020      June 30, 2020
# 1            June 2020       June 3, 2020  November 28, 2020
# 2             May 2020     April 30, 2020      June 30, 2020
# 3           April 2020      April 5, 2020      April 1, 2022
# 4            June 2020       July 1, 2020       July 1, 2021
# ..                 ...                ...                ...
# 995           May 2020     April 15, 2020          July 2020
# 996          June 2020  September 1, 2020   November 1, 2022
# 997          July 2020        August 2020      December 2020
# 998         April 2020     April 17, 2020    August 30, 2020
# 999          July 2020          July 2020       January 2022
#
#                                       OrgFullName   OrgClass  \
# 0    Institut Investigacio Sanitaria Pere Virgili      OTHER
# 1                                    Cardresearch      OTHER
# 2                         Lowell General Hospital      OTHER
# 3                            Sheba Medical Center  OTHER_GOV
# 4              Universidade Federal de Sao Carlos      OTHER
# ..                                            ...        ...
# 995          Combined Military Hospital, Pakistan      OTHER
# 996     Assistance Publique Hopitaux De Marseille      OTHER
# 997           Sound Pharmaceuticals, Incorporated   INDUSTRY
# 998       Federal University of Rio Grande do Sul      OTHER
# 999                       University of Minnesota      OTHER
#
#                                                Keyword  \
# 0
# 1
# 2                              COVID, Laser, Pulmonary
# 3                         Emergency, Surgery, Covid-19
# 4    coronavirus infections, SARS-CoV-2, COVID-19, ...
# ..                                                 ...
# 995
# 996
# 997                 ebselen, SPI-1005, Covid-19, Covid
# 998  COVID-19, Diabetes Mellitus, Glycemic control,...
# 999
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1    Recruiting, Not yet recruiting, Recruiting, No...
# 2                                           Recruiting
# 3                                           Recruiting
# 4
# ..                                                 ...
# 995                                         Recruiting
# 996
# 997
# 998
# 999
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1    Recruiting', 'Not yet recruiting', 'Recruiting...
# 2                                           Recruiting
# 3                                           Recruiting
# 4
# ..                                                 ...
# 995                                         Recruiting
# 996
# 997
# 998
# 999
#
#                                           LocationCity  \
# 0                                                 Reus
# 1    Belo Horizonte, Belo Horizonte, Betim, Ouro Preto
# 2                                               Lowell
# 3                                            Ramat Gan
# 4                                           São Carlos
# ..                                                 ...
# 995                                             Lahore
# 996                                          Marseille
# 997
# 998                                       Porto Alegre
# 999
#
#                     LocationCountry  EnrollmentCount  \
# 0                             Spain           1200.0
# 1    Brazil, Brazil, Brazil, Brazil           1968.0
# 2                     United States             20.0
# 3                            Israel          10000.0
# 4                            Brazil             64.0
# ..                              ...              ...
# 995                        Pakistan            100.0
# 996                          France            216.0
# 997                                             60.0
# 998                          Brazil            149.0
# 999                                           3000.0
#
#                         StdAge Gender
# 0           Adult, Older Adult    All
# 1           Adult, Older Adult    All
# 2           Adult, Older Adult    All
# 3           Adult, Older Adult    All
# 4           Adult, Older Adult    All
# ..                         ...    ...
# 995  Child, Adult, Older Adult    All
# 996         Adult, Older Adult    All
# 997         Adult, Older Adult    All
# 998         Adult, Older Adult    All
# 999         Adult, Older Adult    All
#
# [1000 rows x 16 columns]

# %%
clean_Q1_tempDF1 = change_remove45(Q1_tempDF1)
clean_Q1_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 1       2  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4       5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ..    ...          ...                                                ...
# 995   996  NCT04420247  Efficacy of Chloroquine or Hydroxychloroquine ...
# 996   997  NCT04397718  Hormonal Intervention for the Treatment in Vet...
# 997   998  NCT04352842  Echocardiographic Manifestation in Patient Wit...
# 998   999  NCT04479358  Low-dose Tocilizumab Versus Standard of Care i...
# 999  1000  NCT04432805  Descriptive and Evaluation Study of the Use of...
#
#     StatusVerifiedDate         StartDate      CompletionDate  \
# 0             May 2020    April 15, 2020    October 15, 2020
# 1            June 2020       May 5, 2020            May 2021
# 2            July 2020    September 2020           June 2022
# 3            June 2020     March 1, 2020       March 1, 2021
# 4            June 2020      May 15, 2020  September 30, 2020
# ..                 ...               ...                 ...
# 995          June 2020    April 16, 2020     August 31, 2020
# 996          July 2020      July 6, 2020    December 6, 2020
# 997         April 2020  January 21, 2020       April 8, 2020
# 998          July 2020    August 5, 2020       March 1, 2021
# 999          June 2020     June 15, 2020       June 15, 2021
#
#                                            OrgFullName OrgClass  \
# 0                         University of Milano Bicocca    OTHER
# 1               "Centre Hospitalier Régional dOrléans"    OTHER
# 2                              Meharry Medical College    OTHER
# 3                         University of Milano Bicocca    OTHER
# 4                         University of Milano Bicocca    OTHER
# ..                                                 ...      ...
# 995  Centro de Estudos e Pesquisa em Emergencias Me...    OTHER
# 996              VA Office of Research and Development      FED
# 997                                     RenJi Hospital    OTHER
# 998                              University of Chicago    OTHER
# 999          Assistance Publique Hopitaux De Marseille    OTHER
#
#                                                Keyword  \
# 0     Lung injury, sars-covid-2, coronavirus infection
# 1    Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 2    COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3    Coronavirus, sars-covid-2, coronavirus infecti...
# 4     Coronavirus, sars-covid-2, coronavirus infection
# ..                                                 ...
# 995  VIRAL PNEUMONIA, CORONAVIRUS, COVID-19, COVID,...
# 996
# 997  COVID-19, Echocardiography, cardiac structure,...
# 998                              COVID-19, Tocilizumab
# 999
#
#                                       LocationFacility  \
# 0    Recruiting, Recruiting, Recruiting, Recruiting...
# 1                                           Recruiting
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995                                         Recruiting
# 996     Recruiting, Recruiting, Recruiting, Recruiting
# 997
# 998
# 999                                         Recruiting
#
#                                         LocationStatus  \
# 0    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 1                                           Recruiting
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995                                         Recruiting
# 996  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 997
# 998
# 999                                         Recruiting
#
#                                           LocationCity  \
# 0    Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 1                                              Orléans
# 2                                            Nashville
# 3                                                Monza
# 4                                                Monza
# ..                                                 ...
# 995                                           Curitiba
# 996      West Los Angeles, Brooklyn, New York, Seattle
# 997                                           Shanghai
# 998                                            Chicago
# 999                                          Marseille
#
#                                        LocationCountry  EnrollmentCount  \
# 0    Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 1                                               France             50.0
# 2                                        United States            200.0
# 3                                                Italy            300.0
# 4                                                Italy            500.0
# ..                                                 ...              ...
# 995                                             Brazil            100.0
# 996  United States, United States, United States, U...            198.0
# 997                                              China             51.0
# 998                                      United States            332.0
# 999                                             France            160.0
#
#                  StdAge  Gender
# 0    Adult, Older Adult     All
# 1                 Adult  Female
# 2                 Adult  Female
# 3    Adult, Older Adult     All
# 4    Adult, Older Adult     All
# ..                  ...     ...
# 995  Adult, Older Adult     All
# 996  Adult, Older Adult    Male
# 997  Adult, Older Adult     All
# 998  Adult, Older Adult     All
# 999  Adult, Older Adult  Female
#
# [1000 rows x 16 columns]

# %%
query = 'coronavirus'
quest2URL = f'http://ClinicalTrials.gov/api/query/study_fields?expr={query}\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest2 = requests.get(quest2URL).json()
Quest2
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:28 00:13:26.360',
#   'Expression': 'coronavirus',
#   'NStudiesAvail': 347033,
#   'NStudiesFound': 1472,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'StartDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationFacility',
#    'LocationStatus',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04279795'],
#     'BriefTitle': ['Detection of 2019 Novel Coronavirus in Multiple Organ System and Its Relationship With Clinical Manifestations'],
#     'StatusVerifiedDate': ['February 2020'],
#     'StartDate': ['January 20, 2020'],
#     'CompletionDate': ['February 28, 2021'],
#     'OrgFullName': ['Third Affiliated Hospital, Sun Yat-Sen University'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['2019 Novel Coronavirus'],
#     'LocationFacility': ['The Third Affiliated Hospital of Sun Yat-sen University'],
#     'LocationStatus': ['Recruiting'],
#     'LocationCity': ['Guangzhou'],
#     'LocationCountry': ['China'],
#     'EnrollmentCount': ['20'],
#     'StdAge': ['Child', 'Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
limit2 = Quest2['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit2
# Out:
# 1472

# %%
tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   

tempL1 = requests.get(tempURL1).json()

tempURL2 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk={limit2}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

Q2_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q2_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']

# %%
Q2_tempDF1 = pd.DataFrame(Q2_tempL1)
Q2_tempDF2 = pd.DataFrame(Q2_tempL2)

# %%
clean_Q2_tempDF1 = change_remove45(Q2_tempDF1)
clean_Q2_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1       2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 4       5  NCT04473170  Study Evaluating the Safety and Efficacy of Au...
# ..    ...          ...                                                ...
# 995   996  NCT04449380  Clinical Study for the Treatment With Interfer...
# 996   997  NCT04385849  Study of the Safety of Therapeutic Treatment W...
# 997   998  NCT04323644  Outcomes of Surgery in COVID-19 Infection: Int...
# 998   999  NCT04354441  Effect of Hydroxychloroquine in COVID-19 Posit...
# 999  1000  NCT04362085  Coagulopathy of COVID-19: A Pragmatic Randomiz...
#
#     StatusVerifiedDate        StartDate      CompletionDate  \
# 0            June 2020      May 5, 2020            May 2021
# 1             May 2020   April 15, 2020    October 15, 2020
# 2            July 2020   September 2020           June 2022
# 3           April 2020   April 27, 2020        October 2020
# 4            July 2020    April 4, 2020       July 14, 2020
# ..                 ...              ...                 ...
# 995          June 2020        July 2020          April 2021
# 996           May 2020     June 1, 2020       July 11, 2020
# 997           May 2020  January 1, 2020  September 30, 2020
# 998          June 2020         May 2020            May 2020
# 999           May 2020     May 11, 2020       December 2020
#
#                                          OrgFullName   OrgClass  \
# 0             "Centre Hospitalier Régional dOrléans"      OTHER
# 1                       University of Milano Bicocca      OTHER
# 2                            Meharry Medical College      OTHER
# 3           Centre Hospitalier Universitaire, Amiens      OTHER
# 4                        Abu Dhabi Stem Cells Center  OTHER_GOV
# ..                                               ...        ...
# 995                               IRCCS San Raffaele      OTHER
# 996                                ImmunityBio, Inc.   INDUSTRY
# 997                         University of Birmingham      OTHER
# 998  Sir Mortimer B. Davis - Jewish General Hospital      OTHER
# 999                 "St. Michaels Hospital, Toronto"      OTHER
#
#                                                Keyword  \
# 0    Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1     Lung injury, sars-covid-2, coronavirus infection
# 2    COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3    Hepatocellular Carcinoma, COVID-19, Coronaviru...
# 4    COVID-19, Non-Hematopoietic Peripheral Blood S...
# ..                                                 ...
# 995
# 996
# 997                     COVID-19, Coronavirus, Surgery
# 998  COVID-19, SARS-CoV-2, Pregnancy, hydroxychloro...
# 999                      coagulopathy, anticoagulation
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1    Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                           Recruiting
# 4
# ..                                                 ...
# 995
# 996
# 997                                         Recruiting
# 998
# 999                                         Recruiting
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                           Recruiting
# 4
# ..                                                 ...
# 995
# 996
# 997                                         Recruiting
# 998
# 999                                         Recruiting
#
#                                           LocationCity  \
# 0                                              Orléans
# 1    Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                            Nashville
# 3                                               Amiens
# 4                                            Abu Dhabi
# ..                                                 ...
# 995                                             Milano
# 996
# 997                                             Madrid
# 998
# 999                                            Toronto
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                               France             50.0
# 1    Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                        United States            200.0
# 3                                               France             50.0
# 4                                 United Arab Emirates            146.0
# ..                                                 ...              ...
# 995                                              Italy            126.0
# 996                                                                30.0
# 997                                              Spain           1000.0
# 998                                                                 0.0
# 999                                             Canada            462.0
#
#                         StdAge  Gender
# 0                        Adult  Female
# 1           Adult, Older Adult     All
# 2                        Adult  Female
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 995         Adult, Older Adult     All
# 996         Adult, Older Adult     All
# 997  Child, Adult, Older Adult     All
# 998                      Adult  Female
# 999         Adult, Older Adult     All
#
# [1000 rows x 16 columns]

# %%
clean_Q2_tempDF2 = change_remove45(Q2_tempDF2)
clean_Q2_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04407273              STATIN THERAPY AND COVID-19 INFECTION
# 1    1002  NCT04403100  Hydroxychloroquine and Lopinavir/ Ritonavir to...
# 2    1003  NCT04391712  Cold Laser Therapy for COVID-19 Positive Patie...
# 3    1004  NCT04338672  The Impact of the Covid-19 Outbreak on Emergen...
# 4    1005  NCT04431466  A Study to Compare the Efficacy and Safety of ...
# ..    ...          ...                                                ...
# 467  1468  NCT04409535  Effects of the COVID-19 Health Emergency on Bi...
# 468  1469  NCT04374019  Novel Agents for Treatment of High-risk COVID-...
# 469  1470  NCT04380792  Prevalence of DVT or PE in Patients Infected W...
# 470  1471  NCT04346667  Post-Exposure Prophylaxis for Asymptomatic SAR...
# 471  1472  NCT04410107  Lung Function, Exercise Capacity and Health-Re...
#
#     StatusVerifiedDate       StartDate     CompletionDate  \
# 0             May 2020    May 14, 2020      June 30, 2020
# 1            June 2020    June 3, 2020  November 28, 2020
# 2             May 2020  April 30, 2020      June 30, 2020
# 3           April 2020   April 5, 2020      April 1, 2022
# 4            June 2020    July 1, 2020       July 1, 2021
# ..                 ...             ...                ...
# 467           May 2020     May 7, 2020     March 31, 2021
# 468          July 2020     May 1, 2020           May 2021
# 469           May 2020  April 13, 2020      June 30, 2025
# 470         April 2020  April 14, 2020      June 30, 2021
# 471           May 2020    May 15, 2020     August 2, 2022
#
#                                            OrgFullName   OrgClass  \
# 0         Institut Investigacio Sanitaria Pere Virgili      OTHER
# 1                                         Cardresearch      OTHER
# 2                              Lowell General Hospital      OTHER
# 3                                 Sheba Medical Center  OTHER_GOV
# 4                   Universidade Federal de Sao Carlos      OTHER
# ..                                                 ...        ...
# 467                           University of New Mexico      OTHER
# 468                             University of Kentucky      OTHER
# 469  Foundation for the study of VTE diseases. (FUE...      OTHER
# 470  Government of Punjab, Specialized Healthcare a...  OTHER_GOV
# 471            Federal University of Rio Grande do Sul      OTHER
#
#                                                Keyword  \
# 0
# 1
# 2                              COVID, Laser, Pulmonary
# 3                         Emergency, Surgery, Covid-19
# 4    coronavirus infections, SARS-CoV-2, COVID-19, ...
# ..                                                 ...
# 467         Quality of Life, Rural Community, COVID-19
# 468                                          high-risk
# 469
# 470
# 471  Severe Acute Respiratory Syndrome Coronavirus ...
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1    Recruiting, Not yet recruiting, Recruiting, No...
# 2                                           Recruiting
# 3                                           Recruiting
# 4
# ..                                                 ...
# 467
# 468                                         Recruiting
# 469                                         Recruiting
# 470                 Recruiting, Recruiting, Recruiting
# 471  Recruiting, Not yet recruiting, Recruiting, No...
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1    Recruiting', 'Not yet recruiting', 'Recruiting...
# 2                                           Recruiting
# 3                                           Recruiting
# 4
# ..                                                 ...
# 467
# 468                                         Recruiting
# 469                                         Recruiting
# 470             Recruiting', 'Recruiting', 'Recruiting
# 471  Recruiting', 'Not yet recruiting', 'Recruiting...
#
#                                           LocationCity  \
# 0                                                 Reus
# 1    Belo Horizonte, Belo Horizonte, Betim, Ouro Preto
# 2                                               Lowell
# 3                                            Ramat Gan
# 4                                           São Carlos
# ..                                                 ...
# 467                                        Albuquerque
# 468                                          Lexington
# 469                                           Badalona
# 470                             Lahore, Lahore, Lahore
# 471  Passo Fundo, Porto Alegre, Porto Alegre, Porto...
#
#                             LocationCountry  EnrollmentCount  \
# 0                                     Spain           1200.0
# 1            Brazil, Brazil, Brazil, Brazil           1968.0
# 2                             United States             20.0
# 3                                    Israel          10000.0
# 4                                    Brazil             64.0
# ..                                      ...              ...
# 467                           United States            500.0
# 468                           United States            240.0
# 469                                   Spain           5000.0
# 470            Pakistan, Pakistan, Pakistan            400.0
# 471  Brazil, Brazil, Brazil, Brazil, Brazil            134.0
#
#                         StdAge Gender
# 0           Adult, Older Adult    All
# 1           Adult, Older Adult    All
# 2           Adult, Older Adult    All
# 3           Adult, Older Adult    All
# 4           Adult, Older Adult    All
# ..                         ...    ...
# 467         Adult, Older Adult    All
# 468         Adult, Older Adult    All
# 469  Child, Adult, Older Adult    All
# 470                      Adult    All
# 471  Child, Adult, Older Adult    All
#
# [472 rows x 16 columns]

# %%
DF_QQ = pd.concat([clean_Q1_tempDF1, clean_Q1_tempDF2, clean_Q1_tempDF3, clean_Q2_tempDF1, clean_Q2_tempDF2], ignore_index=True)
DF_QQ = DF_QQ.drop_duplicates()
DF_QQ
# Out:
#       Rank        NCTId                                         BriefTitle  \
# 0        1  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 1        2  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 2        3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3        4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4        5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ...    ...          ...                                                ...
# 3900   996  NCT04449380  Clinical Study for the Treatment With Interfer...
# 3901   997  NCT04385849  Study of the Safety of Therapeutic Treatment W...
# 3902   998  NCT04323644  Outcomes of Surgery in COVID-19 Infection: Int...
# 3903   999  NCT04354441  Effect of Hydroxychloroquine in COVID-19 Posit...
# 3904  1000  NCT04362085  Coagulopathy of COVID-19: A Pragmatic Randomiz...
#
#      StatusVerifiedDate        StartDate      CompletionDate  \
# 0              May 2020   April 15, 2020    October 15, 2020
# 1             June 2020      May 5, 2020            May 2021
# 2             July 2020   September 2020           June 2022
# 3             June 2020    March 1, 2020       March 1, 2021
# 4             June 2020     May 15, 2020  September 30, 2020
# ...                 ...              ...                 ...
# 3900          June 2020        July 2020          April 2021
# 3901           May 2020     June 1, 2020       July 11, 2020
# 3902           May 2020  January 1, 2020  September 30, 2020
# 3903          June 2020         May 2020            May 2020
# 3904           May 2020     May 11, 2020       December 2020
#
#                                           OrgFullName  OrgClass  \
# 0                        University of Milano Bicocca     OTHER
# 1              "Centre Hospitalier Régional dOrléans"     OTHER
# 2                             Meharry Medical College     OTHER
# 3                        University of Milano Bicocca     OTHER
# 4                        University of Milano Bicocca     OTHER
# ...                                               ...       ...
# 3900                               IRCCS San Raffaele     OTHER
# 3901                                ImmunityBio, Inc.  INDUSTRY
# 3902                         University of Birmingham     OTHER
# 3903  Sir Mortimer B. Davis - Jewish General Hospital     OTHER
# 3904                 "St. Michaels Hospital, Toronto"     OTHER
#
#                                                 Keyword  \
# 0      Lung injury, sars-covid-2, coronavirus infection
# 1     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Coronavirus, sars-covid-2, coronavirus infecti...
# 4      Coronavirus, sars-covid-2, coronavirus infection
# ...                                                 ...
# 3900
# 3901
# 3902                     COVID-19, Coronavirus, Surgery
# 3903  COVID-19, SARS-CoV-2, Pregnancy, hydroxychloro...
# 3904                      coagulopathy, anticoagulation
#
#                                        LocationFacility  \
# 0     Recruiting, Recruiting, Recruiting, Recruiting...
# 1                                            Recruiting
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3900
# 3901
# 3902                                         Recruiting
# 3903
# 3904                                         Recruiting
#
#                                          LocationStatus  \
# 0     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 1                                            Recruiting
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3900
# 3901
# 3902                                         Recruiting
# 3903
# 3904                                         Recruiting
#
#                                            LocationCity  \
# 0     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 1                                               Orléans
# 2                                             Nashville
# 3                                                 Monza
# 4                                                 Monza
# ...                                                 ...
# 3900                                             Milano
# 3901
# 3902                                             Madrid
# 3903
# 3904                                            Toronto
#
#                                         LocationCountry  EnrollmentCount  \
# 0     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 1                                                France             50.0
# 2                                         United States            200.0
# 3                                                 Italy            300.0
# 4                                                 Italy            500.0
# ...                                                 ...              ...
# 3900                                              Italy            126.0
# 3901                                                                30.0
# 3902                                              Spain           1000.0
# 3903                                                                 0.0
# 3904                                             Canada            462.0
#
#                          StdAge  Gender
# 0            Adult, Older Adult     All
# 1                         Adult  Female
# 2                         Adult  Female
# 3            Adult, Older Adult     All
# 4            Adult, Older Adult     All
# ...                         ...     ...
# 3900         Adult, Older Adult     All
# 3901         Adult, Older Adult     All
# 3902  Child, Adult, Older Adult     All
# 3903                      Adult  Female
# 3904         Adult, Older Adult     All
#
# [3902 rows x 16 columns]

# %%
dupe_dupe = DF_QQ.pivot_table(index=['NCTId'], aggfunc='size')
print (dupe_dupe)
# Out:
# NCTId
# NCT01306084    1
# NCT02517489    1
# NCT02656381    1
# NCT02735707    1
# NCT02765191    1
#               ..
# NCT04488588    2
# NCT04488796    1
# NCT04489407    1
# NCT04489446    1
# NCT04489628    1
# Length: 2855, dtype: int64

# %%
df_final = DF_QQ.drop_duplicates(subset='NCTId', keep="first")
df_final
# Out:
#       Rank        NCTId                                         BriefTitle  \
# 0        1  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 1        2  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 2        3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3        4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4        5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ...    ...          ...                                                ...
# 3899   995  NCT04346043  To Access the Egyptian COVID-19 Whole Genome b...
# 3900   996  NCT04449380  Clinical Study for the Treatment With Interfer...
# 3901   997  NCT04385849  Study of the Safety of Therapeutic Treatment W...
# 3902   998  NCT04323644  Outcomes of Surgery in COVID-19 Infection: Int...
# 3904  1000  NCT04362085  Coagulopathy of COVID-19: A Pragmatic Randomiz...
#
#      StatusVerifiedDate        StartDate      CompletionDate  \
# 0              May 2020   April 15, 2020    October 15, 2020
# 1             June 2020      May 5, 2020            May 2021
# 2             July 2020   September 2020           June 2022
# 3             June 2020    March 1, 2020       March 1, 2021
# 4             June 2020     May 15, 2020  September 30, 2020
# ...                 ...              ...                 ...
# 3899         April 2020   April 20, 2020    December 1, 2020
# 3900          June 2020        July 2020          April 2021
# 3901           May 2020     June 1, 2020       July 11, 2020
# 3902           May 2020  January 1, 2020  September 30, 2020
# 3904           May 2020     May 11, 2020       December 2020
#
#                                  OrgFullName  OrgClass  \
# 0               University of Milano Bicocca     OTHER
# 1     "Centre Hospitalier Régional dOrléans"     OTHER
# 2                    Meharry Medical College     OTHER
# 3               University of Milano Bicocca     OTHER
# 4               University of Milano Bicocca     OTHER
# ...                                      ...       ...
# 3899                    Ain Shams University     OTHER
# 3900                      IRCCS San Raffaele     OTHER
# 3901                       ImmunityBio, Inc.  INDUSTRY
# 3902                University of Birmingham     OTHER
# 3904        "St. Michaels Hospital, Toronto"     OTHER
#
#                                                 Keyword  \
# 0      Lung injury, sars-covid-2, coronavirus infection
# 1     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Coronavirus, sars-covid-2, coronavirus infecti...
# 4      Coronavirus, sars-covid-2, coronavirus infection
# ...                                                 ...
# 3899                                              Egypt
# 3900
# 3901
# 3902                     COVID-19, Coronavirus, Surgery
# 3904                      coagulopathy, anticoagulation
#
#                                        LocationFacility  \
# 0     Recruiting, Recruiting, Recruiting, Recruiting...
# 1                                            Recruiting
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3899
# 3900
# 3901
# 3902                                         Recruiting
# 3904                                         Recruiting
#
#                                          LocationStatus  \
# 0     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 1                                            Recruiting
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3899
# 3900
# 3901
# 3902                                         Recruiting
# 3904                                         Recruiting
#
#                                            LocationCity  \
# 0     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 1                                               Orléans
# 2                                             Nashville
# 3                                                 Monza
# 4                                                 Monza
# ...                                                 ...
# 3899                                              Cairo
# 3900                                             Milano
# 3901
# 3902                                             Madrid
# 3904                                            Toronto
#
#                                         LocationCountry  EnrollmentCount  \
# 0     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 1                                                France             50.0
# 2                                         United States            200.0
# 3                                                 Italy            300.0
# 4                                                 Italy            500.0
# ...                                                 ...              ...
# 3899                                              Egypt            100.0
# 3900                                              Italy            126.0
# 3901                                                                30.0
# 3902                                              Spain           1000.0
# 3904                                             Canada            462.0
#
#                          StdAge  Gender
# 0            Adult, Older Adult     All
# 1                         Adult  Female
# 2                         Adult  Female
# 3            Adult, Older Adult     All
# 4            Adult, Older Adult     All
# ...                         ...     ...
# 3899         Adult, Older Adult     All
# 3900         Adult, Older Adult     All
# 3901         Adult, Older Adult     All
# 3902  Child, Adult, Older Adult     All
# 3904         Adult, Older Adult     All
#
# [2855 rows x 16 columns]

# %%
df_final.set_index('NCTId', inplace=True)
df_final
# Out:
#              Rank                                         BriefTitle  \
# NCTId
# NCT04395482     1  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# NCT04395924     2         Maternal-foetal Transmission of SARS-Cov-2
# NCT04476940     3  COVID-19 Breastfeeding Guideline for African-A...
# NCT04412265     4          Frailty in Elderly Patients With COVID-19
# NCT04427332     5     Smell and Taste Disorders in COVID-19 Patients
# ...           ...                                                ...
# NCT04346043   995  To Access the Egyptian COVID-19 Whole Genome b...
# NCT04449380   996  Clinical Study for the Treatment With Interfer...
# NCT04385849   997  Study of the Safety of Therapeutic Treatment W...
# NCT04323644   998  Outcomes of Surgery in COVID-19 Infection: Int...
# NCT04362085  1000  Coagulopathy of COVID-19: A Pragmatic Randomiz...
#
#             StatusVerifiedDate        StartDate      CompletionDate  \
# NCTId
# NCT04395482           May 2020   April 15, 2020    October 15, 2020
# NCT04395924          June 2020      May 5, 2020            May 2021
# NCT04476940          July 2020   September 2020           June 2022
# NCT04412265          June 2020    March 1, 2020       March 1, 2021
# NCT04427332          June 2020     May 15, 2020  September 30, 2020
# ...                        ...              ...                 ...
# NCT04346043         April 2020   April 20, 2020    December 1, 2020
# NCT04449380          June 2020        July 2020          April 2021
# NCT04385849           May 2020     June 1, 2020       July 11, 2020
# NCT04323644           May 2020  January 1, 2020  September 30, 2020
# NCT04362085           May 2020     May 11, 2020       December 2020
#
#                                         OrgFullName  OrgClass  \
# NCTId
# NCT04395482            University of Milano Bicocca     OTHER
# NCT04395924  "Centre Hospitalier Régional dOrléans"     OTHER
# NCT04476940                 Meharry Medical College     OTHER
# NCT04412265            University of Milano Bicocca     OTHER
# NCT04427332            University of Milano Bicocca     OTHER
# ...                                             ...       ...
# NCT04346043                    Ain Shams University     OTHER
# NCT04449380                      IRCCS San Raffaele     OTHER
# NCT04385849                       ImmunityBio, Inc.  INDUSTRY
# NCT04323644                University of Birmingham     OTHER
# NCT04362085        "St. Michaels Hospital, Toronto"     OTHER
#
#                                                        Keyword  \
# NCTId
# NCT04395482   Lung injury, sars-covid-2, coronavirus infection
# NCT04395924  Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# NCT04476940  COVID-19, Exclusive Breastfeeding, Breastfeedi...
# NCT04412265  Coronavirus, sars-covid-2, coronavirus infecti...
# NCT04427332   Coronavirus, sars-covid-2, coronavirus infection
# ...                                                        ...
# NCT04346043                                              Egypt
# NCT04449380
# NCT04385849
# NCT04323644                     COVID-19, Coronavirus, Surgery
# NCT04362085                      coagulopathy, anticoagulation
#
#                                               LocationFacility  \
# NCTId
# NCT04395482  Recruiting, Recruiting, Recruiting, Recruiting...
# NCT04395924                                         Recruiting
# NCT04476940
# NCT04412265                                         Recruiting
# NCT04427332                                         Recruiting
# ...                                                        ...
# NCT04346043
# NCT04449380
# NCT04385849
# NCT04323644                                         Recruiting
# NCT04362085                                         Recruiting
#
#                                                 LocationStatus  \
# NCTId
# NCT04395482  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# NCT04395924                                         Recruiting
# NCT04476940
# NCT04412265                                         Recruiting
# NCT04427332                                         Recruiting
# ...                                                        ...
# NCT04346043
# NCT04449380
# NCT04385849
# NCT04323644                                         Recruiting
# NCT04362085                                         Recruiting
#
#                                                   LocationCity  \
# NCTId
# NCT04395482  Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# NCT04395924                                            Orléans
# NCT04476940                                          Nashville
# NCT04412265                                              Monza
# NCT04427332                                              Monza
# ...                                                        ...
# NCT04346043                                              Cairo
# NCT04449380                                             Milano
# NCT04385849
# NCT04323644                                             Madrid
# NCT04362085                                            Toronto
#
#                                                LocationCountry  \
# NCTId
# NCT04395482  Italy, Italy, Italy, Italy, Italy, Italy, Ital...
# NCT04395924                                             France
# NCT04476940                                      United States
# NCT04412265                                              Italy
# NCT04427332                                              Italy
# ...                                                        ...
# NCT04346043                                              Egypt
# NCT04449380                                              Italy
# NCT04385849
# NCT04323644                                              Spain
# NCT04362085                                             Canada
#
#              EnrollmentCount                     StdAge  Gender
# NCTId
# NCT04395482            500.0         Adult, Older Adult     All
# NCT04395924             50.0                      Adult  Female
# NCT04476940            200.0                      Adult  Female
# NCT04412265            300.0         Adult, Older Adult     All
# NCT04427332            500.0         Adult, Older Adult     All
# ...                      ...                        ...     ...
# NCT04346043            100.0         Adult, Older Adult     All
# NCT04449380            126.0         Adult, Older Adult     All
# NCT04385849             30.0         Adult, Older Adult     All
# NCT04323644           1000.0  Child, Adult, Older Adult     All
# NCT04362085            462.0         Adult, Older Adult     All
#
# [2855 rows x 15 columns]

# %%
bins = [0, 100, 250, 500, 1000, 2500, 5000, 10000, 50000, 100000, 1000000000]
df_final['binned'] = pd.cut(df_final['EnrollmentCount'], bins)
df_final
# Out:
# /opt/anaconda3/envs/PythonData3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              Rank                                         BriefTitle  \
# NCTId
# NCT04395482     1  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# NCT04395924     2         Maternal-foetal Transmission of SARS-Cov-2
# NCT04476940     3  COVID-19 Breastfeeding Guideline for African-A...
# NCT04412265     4          Frailty in Elderly Patients With COVID-19
# NCT04427332     5     Smell and Taste Disorders in COVID-19 Patients
# ...           ...                                                ...
# NCT04346043   995  To Access the Egyptian COVID-19 Whole Genome b...
# NCT04449380   996  Clinical Study for the Treatment With Interfer...
# NCT04385849   997  Study of the Safety of Therapeutic Treatment W...
# NCT04323644   998  Outcomes of Surgery in COVID-19 Infection: Int...
# NCT04362085  1000  Coagulopathy of COVID-19: A Pragmatic Randomiz...
#
#             StatusVerifiedDate        StartDate      CompletionDate  \
# NCTId
# NCT04395482           May 2020   April 15, 2020    October 15, 2020
# NCT04395924          June 2020      May 5, 2020            May 2021
# NCT04476940          July 2020   September 2020           June 2022
# NCT04412265          June 2020    March 1, 2020       March 1, 2021
# NCT04427332          June 2020     May 15, 2020  September 30, 2020
# ...                        ...              ...                 ...
# NCT04346043         April 2020   April 20, 2020    December 1, 2020
# NCT04449380          June 2020        July 2020          April 2021
# NCT04385849           May 2020     June 1, 2020       July 11, 2020
# NCT04323644           May 2020  January 1, 2020  September 30, 2020
# NCT04362085           May 2020     May 11, 2020       December 2020
#
#                                         OrgFullName  OrgClass  \
# NCTId
# NCT04395482            University of Milano Bicocca     OTHER
# NCT04395924  "Centre Hospitalier Régional dOrléans"     OTHER
# NCT04476940                 Meharry Medical College     OTHER
# NCT04412265            University of Milano Bicocca     OTHER
# NCT04427332            University of Milano Bicocca     OTHER
# ...                                             ...       ...
# NCT04346043                    Ain Shams University     OTHER
# NCT04449380                      IRCCS San Raffaele     OTHER
# NCT04385849                       ImmunityBio, Inc.  INDUSTRY
# NCT04323644                University of Birmingham     OTHER
# NCT04362085        "St. Michaels Hospital, Toronto"     OTHER
#
#                                                        Keyword  \
# NCTId
# NCT04395482   Lung injury, sars-covid-2, coronavirus infection
# NCT04395924  Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# NCT04476940  COVID-19, Exclusive Breastfeeding, Breastfeedi...
# NCT04412265  Coronavirus, sars-covid-2, coronavirus infecti...
# NCT04427332   Coronavirus, sars-covid-2, coronavirus infection
# ...                                                        ...
# NCT04346043                                              Egypt
# NCT04449380
# NCT04385849
# NCT04323644                     COVID-19, Coronavirus, Surgery
# NCT04362085                      coagulopathy, anticoagulation
#
#                                               LocationFacility  \
# NCTId
# NCT04395482  Recruiting, Recruiting, Recruiting, Recruiting...
# NCT04395924                                         Recruiting
# NCT04476940
# NCT04412265                                         Recruiting
# NCT04427332                                         Recruiting
# ...                                                        ...
# NCT04346043
# NCT04449380
# NCT04385849
# NCT04323644                                         Recruiting
# NCT04362085                                         Recruiting
#
#                                                 LocationStatus  \
# NCTId
# NCT04395482  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# NCT04395924                                         Recruiting
# NCT04476940
# NCT04412265                                         Recruiting
# NCT04427332                                         Recruiting
# ...                                                        ...
# NCT04346043
# NCT04449380
# NCT04385849
# NCT04323644                                         Recruiting
# NCT04362085                                         Recruiting
#
#                                                   LocationCity  \
# NCTId
# NCT04395482  Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# NCT04395924                                            Orléans
# NCT04476940                                          Nashville
# NCT04412265                                              Monza
# NCT04427332                                              Monza
# ...                                                        ...
# NCT04346043                                              Cairo
# NCT04449380                                             Milano
# NCT04385849
# NCT04323644                                             Madrid
# NCT04362085                                            Toronto
#
#                                                LocationCountry  \
# NCTId
# NCT04395482  Italy, Italy, Italy, Italy, Italy, Italy, Ital...
# NCT04395924                                             France
# NCT04476940                                      United States
# NCT04412265                                              Italy
# NCT04427332                                              Italy
# ...                                                        ...
# NCT04346043                                              Egypt
# NCT04449380                                              Italy
# NCT04385849
# NCT04323644                                              Spain
# NCT04362085                                             Canada
#
#              EnrollmentCount                     StdAge  Gender       binned
# NCTId
# NCT04395482            500.0         Adult, Older Adult     All   (250, 500]
# NCT04395924             50.0                      Adult  Female     (0, 100]
# NCT04476940            200.0                      Adult  Female   (100, 250]
# NCT04412265            300.0         Adult, Older Adult     All   (250, 500]
# NCT04427332            500.0         Adult, Older Adult     All   (250, 500]
# ...                      ...                        ...     ...          ...
# NCT04346043            100.0         Adult, Older Adult     All     (0, 100]
# NCT04449380            126.0         Adult, Older Adult     All   (100, 250]
# NCT04385849             30.0         Adult, Older Adult     All     (0, 100]
# NCT04323644           1000.0  Child, Adult, Older Adult     All  (500, 1000]
# NCT04362085            462.0         Adult, Older Adult     All   (250, 500]
#
# [2855 rows x 16 columns]

# %%
df_enrollment = df_final.groupby("binned")[["BriefTitle"]].count()

# %%
df_enrollment = df_enrollment.reset_index()
df_enrollment
# Out:
#                  binned  BriefTitle
# 0              (0, 100]        1107
# 1            (100, 250]         564
# 2            (250, 500]         427
# 3           (500, 1000]         285
# 4          (1000, 2500]         192
# 5          (2500, 5000]          97
# 6         (5000, 10000]          55
# 7        (10000, 50000]          49
# 8       (50000, 100000]          12
# 9  (100000, 1000000000]          21

# %%
enrollment_bar = df_enrollment.plot.bar(x='binned', y='BriefTitle', rot=45, legend=False, color="r")
plt.xlabel('Participants per Study')
plt.ylabel('Number of Studies')
plt.title('Number of Studies by Enrollment')
# Out:
# Text(0.5, 1.0, 'Number of Studies by Enrollment')

# %%
df_age = df_final.groupby("StdAge")[["BriefTitle"]].count()
df_age
# Out:
#                            BriefTitle
# StdAge
# Adult                             146
# Adult, Older Adult               2161
# Child                              27
# Child, Adult                       42
# Child, Adult, Older Adult         445
# Older Adult                        34

# %%
df_age = df_age.reset_index()
df_age
# Out:
#                       StdAge  BriefTitle
# 0                      Adult         146
# 1         Adult, Older Adult        2161
# 2                      Child          27
# 3               Child, Adult          42
# 4  Child, Adult, Older Adult         445
# 5                Older Adult          34

# %%
df_age = df_age.sort_values(by='BriefTitle', ascending=False)
df_age
# Out:
#                       StdAge  BriefTitle
# 1         Adult, Older Adult        2161
# 4  Child, Adult, Older Adult         445
# 0                      Adult         146
# 3               Child, Adult          42
# 5                Older Adult          34
# 2                      Child          27

# %%
age_bar = df_age.plot.barh(x='StdAge', y='BriefTitle', rot=0, legend=False)
plt.xlabel('Number of Studies')
plt.ylabel('Target Age Group(s)')
plt.title('Number of Studies by Target Age Group')
# Out:
# Text(0.5, 1.0, 'Number of Studies by Target Age Group')

# %%
df_gender = df_final.groupby("Gender")[["BriefTitle"]].count()
df_gender
# Out:
#         BriefTitle
# Gender
#                  5
# All           2760
# Female          70
# Male            20

# %%
df_gender_clean = df_gender.drop("")
df_gender_clean = df_gender_clean.reset_index()
df_gender_clean
# Out:
#    Gender  BriefTitle
# 0     All        2760
# 1  Female          70
# 2    Male          20

# %%
import squarify
color_list = ['#b2790c', '#ffe9a3',
              '#f9d4d4', '#d35158', '#ea3033']
perc = [str('{:5.2f}'.format(i/df_gender_clean['BriefTitle'].sum()*100)) + "%" for i in df_gender_clean['BriefTitle']]
lbl = [el[0] + " = " + el[1] for el in zip(df_gender_clean['Gender'], perc)]
plt.plot(range(10))
squarify.plot(sizes=df_gender_clean['BriefTitle'], label=lbl, alpha=.8, color=color_list)
ax = plt.gca()
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
plt.title("Eligible Gender(s) of Participants for each Study")
plt.show()
