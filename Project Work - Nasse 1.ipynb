# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
questURL = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest = requests.get(questURL).json()
Quest
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:24 00:13:26.663',
#   'Expression': 'covid 19',
#   'NStudiesAvail': 346767,
#   'NStudiesFound': 2874,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04395482'],
#     'BriefTitle': ['Lung CT Scan Analysis of SARS-CoV2 Induced Lung Injury'],
#     'StatusVerifiedDate': ['May 2020'],
#     'CompletionDate': ['October 15, 2020'],
#     'OrgFullName': ['University of Milano Bicocca'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['Lung injury', 'sars-covid-2', 'coronavirus infection'],
#     'LocationCity': ['Bergamo',
#      'Bergamo',
#      'Ferrara',
#      'Lecco',
#      'Melzo',
#      'Monza',
#      'Rimini',
#      'San Marino'],
#     'LocationCountry': ['Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'San Marino'],
#     'EnrollmentCount': ['500'],
#     'StdAge': ['Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
limit1 = Quest['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit1
# Out:
# 2874

# %%
tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   
tempL1 = requests.get(tempURL1).json()

tempURL2 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk=2000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

tempURL3 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=2001\
           &max_rnk={limit1}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL3 = requests.get(tempURL3).json()

Q1_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q1_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']
Q1_tempL3 = tempL3['StudyFieldsResponse']['StudyFields']

# %%
Q1_tempDF1 = pd.DataFrame(Q1_tempL1)
Q1_tempDF2 = pd.DataFrame(Q1_tempL2)
Q1_tempDF3 = pd.DataFrame(Q1_tempL3)

# %%
Q1_tempDF1
# Out:
#      Rank          NCTId                                         BriefTitle  \
# 0       1  [NCT04395924]       [Maternal-foetal Transmission of SARS-Cov-2]
# 1       2  [NCT04395482]  [Lung CT Scan Analysis of SARS-CoV2 Induced Lu...
# 2       3  [NCT04476940]  [COVID-19 Breastfeeding Guideline for African-...
# 3       4  [NCT04367805]  [COVID-19 Infection in Patients With Hepatocel...
# 4       5  [NCT04412265]        [Frailty in Elderly Patients With COVID-19]
# ..    ...            ...                                                ...
# 995   996  [NCT04392531]  [Clinical Trial to Assess Efficacy of cYclospo...
# 996   997  [NCT04424771]  [Post-traumatic Stress Disease in Health Worke...
# 997   998  [NCT04361214]            [Leflunomide in Mild COVID-19 Patients]
# 998   999  [NCT04418609]  [Neuro-COVID-19: Neurological Complications of...
# 999  1000  [NCT04401540]   [Characteristics of Neonatal Covid-19 in Turkey]
#
#     StatusVerifiedDate         StartDate       CompletionDate  \
# 0          [June 2020]     [May 5, 2020]           [May 2021]
# 1           [May 2020]  [April 15, 2020]   [October 15, 2020]
# 2          [July 2020]  [September 2020]          [June 2022]
# 3         [April 2020]  [April 27, 2020]       [October 2020]
# 4          [June 2020]   [March 1, 2020]      [March 1, 2021]
# ..                 ...               ...                  ...
# 995         [May 2020]  [April 16, 2020]          [July 2020]
# 996        [June 2020]   [March 1, 2020]       [July 1, 2020]
# 997         [May 2020]     [May 5, 2020]          [July 2020]
# 998        [June 2020]     [May 1, 2020]       [May 30, 2022]
# 999        [July 2020]     [May 1, 2020]  [December 30, 2020]
#
#                                            OrgFullName OrgClass  \
# 0              [Centre Hospitalier Régional d'Orléans]  [OTHER]
# 1                       [University of Milano Bicocca]  [OTHER]
# 2                            [Meharry Medical College]  [OTHER]
# 3           [Centre Hospitalier Universitaire, Amiens]  [OTHER]
# 4                       [University of Milano Bicocca]  [OTHER]
# ..                                                 ...      ...
# 995  [Instituto de Investigación Sanitaria de la Fu...  [OTHER]
# 996                 [Ospedale Policlinico San Martino]  [OTHER]
# 997                            [University of Chicago]  [OTHER]
# 998                             [University of Zurich]  [OTHER]
# 999  [Recep Tayyip Erdogan University Training and ...  [OTHER]
#
#                                                Keyword  \
# 0    [Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolo...
# 1    [Lung injury, sars-covid-2, coronavirus infect...
# 2    [COVID-19, Exclusive Breastfeeding, Breastfeed...
# 3    [Hepatocellular Carcinoma, COVID-19, Coronavir...
# 4    [Coronavirus, sars-covid-2, coronavirus infect...
# ..                                                 ...
# 995                                                 []
# 996                                         [COVID-19]
# 997                                      [leflunomide]
# 998                                                 []
# 999                            [Vertical Transmission]
#
#                                       LocationFacility  \
# 0                                        [CHR Orléans]
# 1    [Ospedale Papa Giovanni XXIII, Policlinico San...
# 2                            [Meharry Medical College]
# 3                                         [CHU Amiens]
# 4                    [ASST Monza-Ospedale San Gerardo]
# ..                                                 ...
# 995  [Complejo Hospitalario Universitario La Coruña...
# 996  [Ospedale Perrino Asl Brindisi, IRCCS Ospedale...
# 997                            [University of Chicago]
# 998                       [University Hospital Zurich]
# 999   [Recep Tayyip Erdogan University Medical School]
#
#                                         LocationStatus  \
# 0                                         [Recruiting]
# 1    [Recruiting, Recruiting, Recruiting, Recruitin...
# 2                                                   []
# 3                                         [Recruiting]
# 4                                         [Recruiting]
# ..                                                 ...
# 995  [Recruiting, Recruiting, Recruiting, Recruitin...
# 996                           [Recruiting, Recruiting]
# 997                                       [Recruiting]
# 998                                       [Recruiting]
# 999                                       [Recruiting]
#
#                                           LocationCity  \
# 0                                            [Orléans]
# 1    [Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monz...
# 2                                          [Nashville]
# 3                                             [Amiens]
# 4                                              [Monza]
# ..                                                 ...
# 995  [La Coruña, La Coruña, Mostoles, Valdemoro, Vi...
# 996                                  [Brindisi, Genoa]
# 997                                          [Chicago]
# 998                                           [Zürich]
# 999                                             [Rize]
#
#                                        LocationCountry EnrollmentCount  \
# 0                                             [France]            [50]
# 1    [Italy, Italy, Italy, Italy, Italy, Italy, Ita...           [500]
# 2                                      [United States]           [200]
# 3                                             [France]            [50]
# 4                                              [Italy]           [300]
# ..                                                 ...             ...
# 995  [Spain, Spain, Spain, Spain, Spain, Spain, Spain]           [120]
# 996                                     [Italy, Italy]           [800]
# 997                                    [United States]            [20]
# 998                                      [Switzerland]            [30]
# 999                                           [Turkey]            [90]
#
#                    StdAge    Gender
# 0                 [Adult]  [Female]
# 1    [Adult, Older Adult]     [All]
# 2                 [Adult]  [Female]
# 3    [Adult, Older Adult]     [All]
# 4    [Adult, Older Adult]     [All]
# ..                    ...       ...
# 995  [Adult, Older Adult]     [All]
# 996  [Adult, Older Adult]     [All]
# 997  [Adult, Older Adult]     [All]
# 998  [Adult, Older Adult]     [All]
# 999               [Child]     [All]
#
# [1000 rows x 16 columns]

# %%
Q1_tempDF1
# Out:
#      Rank            NCTId                                         BriefTitle  \
# 0       1  ['NCT04395482']  ['Lung CT Scan Analysis of SARS-CoV2 Induced L...
# 1       2  ['NCT04395924']     ['Maternal-foetal Transmission of SARS-Cov-2']
# 2       3  ['NCT04476940']  ['COVID-19 Breastfeeding Guideline for African...
# 3       4  ['NCT04412265']      ['Frailty in Elderly Patients With COVID-19']
# 4       5  ['NCT04427332']  ['Smell and Taste Disorders in COVID-19 Patien...
# ..    ...              ...                                                ...
# 995   996  ['NCT04362969']  ['COVID-EC Study: Clinical Characteristics of ...
# 996   997  ['NCT04477993']  ['Ruxolitinib for Acute Respiratory Disorder S...
# 997   998  ['NCT04413435']  ['Clinical Characteristics of Critically Ill P...
# 998   999  ['NCT04402905']  ['Observational Study in Diagnosed Patients CO...
# 999  1000  ['NCT04445402']  ['Pediatrics HOT COVID-19 Database in NY Trist...
#
#     StatusVerifiedDate      CompletionDate  \
# 0         ['May 2020']    October 15, 2020
# 1        ['June 2020']            May 2021
# 2        ['July 2020']           June 2022
# 3        ['June 2020']       March 1, 2021
# 4        ['June 2020']  September 30, 2020
# ..                 ...                 ...
# 995       ['May 2020']            May 2020
# 996      ['July 2020']   December 31, 2021
# 997      ['June 2020']       July 25, 2020
# 998       ['May 2020']     August 15, 2020
# 999      ['June 2020']         May 1, 2022
#
#                                            OrgFullName       OrgClass  \
# 0                     ['University of Milano Bicocca']      ['OTHER']
# 1            ["Centre Hospitalier Régional d'Orléans"]      ['OTHER']
# 2                          ['Meharry Medical College']      ['OTHER']
# 3                     ['University of Milano Bicocca']      ['OTHER']
# 4                     ['University of Milano Bicocca']      ['OTHER']
# ..                                                 ...            ...
# 995                    ['Hospital San Carlos, Madrid']      ['OTHER']
# 996       ['University of Sao Paulo General Hospital']      ['OTHER']
# 997                       ['Nevsehir Public Hospital']  ['OTHER_GOV']
# 998  ["Centre de Recherches et d'Etude sur la Patho...      ['OTHER']
# 999                            ['Columbia University']      ['OTHER']
#
#                                                Keyword  \
# 0    ['Lung injury', 'sars-covid-2', 'coronavirus i...
# 1    ['Pregnancy', 'RT-PCR-COVID-19', 'SARS-CoV 2 s...
# 2    ['COVID-19', 'Exclusive Breastfeeding', 'Breas...
# 3    ['Coronavirus', 'sars-covid-2', 'coronavirus i...
# 4    ['Coronavirus', 'sars-covid-2', 'coronavirus i...
# ..                                                 ...
# 995                                                 []
# 996  ['SARS-CoV2', 'Severe Acute Respiratory Syndro...
# 997                                                 []
# 998                                                 []
# 999  ['Immune System Disorder in Children', 'Immune...
#
#                                           LocationCity  \
# 0    ['Bergamo', 'Bergamo', 'Ferrara', 'Lecco', 'Me...
# 1                                          ['Orléans']
# 2                                        ['Nashville']
# 3                                            ['Monza']
# 4                                            ['Monza']
# ..                                                 ...
# 995                                      ['Guayaquil']
# 996                                      ['Sao Paulo']
# 997                                          ['Konya']
# 998                                          ['Paris']
# 999  ['Hartford', 'New Haven', 'Hackensack', 'Morri...
#
#                                        LocationCountry EnrollmentCount  \
# 0    ['Italy', 'Italy', 'Italy', 'Italy', 'Italy', ...         ['500']
# 1                                           ['France']          ['50']
# 2                                    ['United States']         ['200']
# 3                                            ['Italy']         ['300']
# 4                                            ['Italy']         ['500']
# ..                                                 ...             ...
# 995                                        ['Ecuador']         ['300']
# 996                                         ['Brazil']         ['200']
# 997                                         ['Turkey']         ['105']
# 998                                         ['France']         ['450']
# 999  ['United States', 'United States', 'United Sta...        ['1500']
#
#                        StdAge      Gender
# 0    ['Adult', 'Older Adult']     ['All']
# 1                   ['Adult']  ['Female']
# 2                   ['Adult']  ['Female']
# 3    ['Adult', 'Older Adult']     ['All']
# 4    ['Adult', 'Older Adult']     ['All']
# ..                        ...         ...
# 995  ['Adult', 'Older Adult']     ['All']
# 996  ['Adult', 'Older Adult']     ['All']
# 997  ['Adult', 'Older Adult']     ['All']
# 998  ['Adult', 'Older Adult']     ['All']
# 999        ['Child', 'Adult']     ['All']
#
# [1000 rows x 13 columns]

# %%
def change_remove1(df):
    df = df.astype(str)
    df["NCTId"] = df["NCTId"].str.lstrip("['")
    df["NCTId"] = df["NCTId"].str.rstrip("']")
    df["BriefTitle"] = df["BriefTitle"].str.lstrip("['")
    df["BriefTitle"] = df["BriefTitle"].str.rstrip("']")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.lstrip("['")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.rstrip("']")
    df["CompletionDate"] = df["CompletionDate"].str.lstrip("['")
    df["CompletionDate"] = df["CompletionDate"].str.rstrip("']")
    df["OrgFullName"] = df["OrgFullName"].str.lstrip("['")
    df["OrgFullName"] = df["OrgFullName"].str.rstrip("']")
    df["OrgClass"] = df["OrgClass"].str.lstrip("['")
    df["OrgClass"] = df["OrgClass"].str.rstrip("']")
    df["Keyword"] = df["Keyword"].str.lstrip("['")
    df["Keyword"] = df["Keyword"].str.rstrip("']")
    df["LocationCity"] = df["LocationCity"].str.lstrip("['")
    df["LocationCity"] = df["LocationCity"].str.rstrip("']")
    df["LocationCountry"] = df["LocationCountry"].str.lstrip("['")
    df["LocationCountry"] = df["LocationCountry"].str.rstrip("']")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.lstrip("['")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.rstrip("']")
    df["StdAge"] = df["StdAge"].str.lstrip("['")
    df["StdAge"] = df["StdAge"].str.rstrip("']")
    df["Gender"] = df["Gender"].str.lstrip("['")
    df["Gender"] = df["Gender"].str.rstrip("']")
    return df

# %%
clean2 = change_remove1(Q1_tempDF2)
clean2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04445402    Pediatrics HOT COVID-19 Database in NY Tristate
# 1    1002  NCT04400448  Acceptance of Telemedicine During the COVID-19...
# 2    1003  NCT04466540  Randomized Placebo-controlled Trial of Hydroxy...
# 3    1004  NCT04324996  A Phase I/II Study of Universal Off-the-shelf ...
# 4    1005  NCT04443868  Nitric Oxide Releasing Solution to Treat and P...
# ..    ...          ...                                                ...
# 995  1996  NCT04348695  Study of Ruxolitinib Plus Simvastatin in the P...
# 996  1997  NCT04463628  Impacts of the Covid-19 Epidemic and Associate...
# 997  1998  NCT04394000  Impact of an Intensified Thromboprofylaxis Pro...
# 998  1999  NCT04392401  COVID-19 - Study of the Kinetics of the Immune...
# 999  2000  NCT04459364  The Prevalence of Pulmonary Hypertension in Pa...
#
#     StatusVerifiedDate      CompletionDate  \
# 0            June 2020         May 1, 2022
# 1             May 2020    October 31, 2020
# 2            July 2020   December 30, 2020
# 3           March 2020  September 30, 2020
# 4            June 2020           July 2021
# ..                 ...                 ...
# 995         April 2020        May 13, 2020
# 996          July 2020       June 30, 2021
# 997           May 2020        May 15, 2020
# 998           May 2020       February 2021
# 999          July 2020       July 10, 2020
#
#                                            OrgFullName  OrgClass  \
# 0                                  Columbia University     OTHER
# 1    Fundación para el Fomento de la Investigación ...     OTHER
# 2                         Hospital Alemão Oswaldo Cruz     OTHER
# 3               Chongqing Public Health Medical Center     OTHER
# 4              Sanotize Research and Development corp.  INDUSTRY
# ..                                                 ...       ...
# 995                      Fundación de investigación HM     OTHER
# 996           Centre Hospitalier Intercommunal Creteil     OTHER
# 997                                     Jessa Hospital     OTHER
# 998                            Hospices Civils de Lyon     OTHER
# 999                                         Attgeno AB  INDUSTRY
#
#                                                Keyword  \
# 0    Immune System Disorder in Children', 'Immune S...
# 1       telemedicine', 'patient acceptance', 'covid-19
# 2    COVID-19', 'Severe Acute Respiratory Syndrome ...
# 3    NKG2D-ACE2 CAR-NK', 'IL15 superagonist', 'GM-C...
# 4
# ..                                                 ...
# 995              COVID19', 'simvastatin', 'ruxolitinib
# 996  Lockdown', 'Covid-19 Epidemic', 'questionnaire...
# 997
# 998
# 999
#
#                                           LocationCity  \
# 0    Hartford', 'New Haven', 'Hackensack', 'Morrist...
# 1
# 2    Maceió', 'Ipiaú', 'Salvador', 'Salvador', 'Sal...
# 3                                            Chongqing
# 4
# ..                                                 ...
# 995                                             Madrid
# 996                       Creteil', 'Paris', 'Suresnes
# 997                                            Hasselt
# 998  Bron', 'Clermont-Ferrand', 'Grenoble', 'Lyon',...
# 999                                          Stockholm
#
#                                        LocationCountry EnrollmentCount  \
# 0    United States', 'United States', 'United State...            1500
# 1                                                                  200
# 2    Brazil', 'Brazil', 'Brazil', 'Brazil', 'Brazil...            1300
# 3                                                China              90
# 4                                                                  300
# ..                                                 ...             ...
# 995                                              Spain              94
# 996                         France', 'France', 'France            1200
# 997                                            Belgium              72
# 998  France', 'France', 'France', 'France', 'France...             200
# 999                                             Sweden              80
#
#                             StdAge Gender
# 0                   Child', 'Adult    All
# 1             Adult', 'Older Adult    All
# 2             Adult', 'Older Adult    All
# 3             Adult', 'Older Adult    All
# 4             Adult', 'Older Adult    All
# ..                             ...    ...
# 995           Adult', 'Older Adult    All
# 996  Child', 'Adult', 'Older Adult    All
# 997           Adult', 'Older Adult    All
# 998           Adult', 'Older Adult    All
# 999           Adult', 'Older Adult    All
#
# [1000 rows x 13 columns]

# %%
def change_remove45(df):
    df = df.astype(str)
    df["NCTId"] = df["NCTId"].str.lstrip("['")
    df["NCTId"] = df["NCTId"].str.rstrip("']")
    df["BriefTitle"] = df["BriefTitle"].str.lstrip("['")
    df["BriefTitle"] = df["BriefTitle"].str.rstrip("']")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.lstrip("['")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.rstrip("']")
    df["CompletionDate"] = df["CompletionDate"].str.lstrip("['")
    df["CompletionDate"] = df["CompletionDate"].str.rstrip("']")
    df["OrgFullName"] = df["OrgFullName"].str.lstrip("['")
    df["OrgFullName"] = df["OrgFullName"].str.rstrip("']")
    df["OrgClass"] = df["OrgClass"].str.lstrip("['")
    df["OrgClass"] = df["OrgClass"].str.rstrip("']")
    df["Keyword"] = df["Keyword"].str.lstrip("['")
    df["Keyword"] = df["Keyword"].str.rstrip("']")
    df["LocationCity"] = df["LocationCity"].str.lstrip("['")
    df["LocationCity"] = df["LocationCity"].str.rstrip("']")
    df["LocationCountry"] = df["LocationCountry"].str.lstrip("['")
    df["LocationCountry"] = df["LocationCountry"].str.rstrip("']")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.lstrip("['")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.rstrip("']")
    df["StdAge"] = df["StdAge"].str.lstrip("['")
    df["StdAge"] = df["StdAge"].str.rstrip("']")
    df["Gender"] = df["Gender"].str.lstrip("['")
    df["Gender"] = df["Gender"].str.rstrip("']")
    df["LocationFacility"] = df["LocationFacility"].str.lstrip("['")
    df["LocationFacility"] = df["LocationFacility"].str.rstrip("']")
    df["StartDate"] = df["StartDate"].str.lstrip("['")
    df["StartDate"] = df["StartDate"].str.rstrip("']")
    df["LocationStatus"] = df["LocationStatus"].str.lstrip("['")
    df["LocationStatus"] = df["LocationStatus"].str.rstrip("']")
    df["NCTId"] = df["NCTId"].str.replace("'","")
    df["BriefTitle"] = df["BriefTitle"].str.replace("'","")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.replace("'","")
    df["CompletionDate"] = df["CompletionDate"].str.replace("'","")
    df["OrgFullName"] = df["OrgFullName"].str.replace("'","")
    df["OrgClass"] = df["OrgClass"].str.replace("'","")
    df["Keyword"] = df["Keyword"].str.replace("'","")
    df["LocationCity"] = df["LocationCity"].str.replace("'","")
    df["LocationCountry"] = df["LocationCountry"].str.replace("'","")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.replace("'","")
    df["StdAge"] = df["StdAge"].str.replace("'","")
    df["Gender"] = df["Gender"].str.replace("'","")
    df["StartDate"] = df["StartDate"].str.replace("'","")
    df["LocationFacility"] = df["LocationFacility"].str.replace("'","")
    df["LocationFacility"] = df["LocationStatus"].str.replace("'","")
    df["EnrollmentCount"] = pd.to_numeric(df["EnrollmentCount"])
    return df

# %%
clean_Q1_tempDF3 = change_remove45(Q1_tempDF3)
clean_Q1_tempDF3
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    2001  NCT04371562  Predicting Death and ICU Admission in COVID-19...
# 1    2002  NCT04402983  The Effectiveness of Telerehabilitation-Based ...
# 2    2003  NCT04310865  Yinhu Qingwen Granula for the Treatment of Sev...
# 3    2004  NCT04416009          Extracellular Water in Covid 19 Pneumonia
# 4    2005  NCT04466982  Assessment of Olfactory Dysfunction in SARS Co...
# ..    ...          ...                                                ...
# 869  2870  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 870  2871  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 871  2872  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 872  2873  NCT03922334                        Navigating New Motherhood 2
# 873  2874  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#     StatusVerifiedDate         StartDate     CompletionDate  \
# 0           April 2020     March 1, 2020     April 15, 2020
# 1             May 2020      May 20, 2020   December 1, 2020
# 2             May 2020     November 2020      June 30, 2021
# 3            June 2020      July 5, 2020  February 20, 2021
# 4            July 2020      July 2, 2020       January 2022
# ..                 ...               ...                ...
# 869          June 2020    March 25, 2019      April 8, 2022
# 870           May 2020      May 20, 2019      February 2022
# 871          June 2020     March 1, 2020      June 30, 2023
# 872          June 2020  January 21, 2020      December 2024
# 873          June 2020   August 31, 2020  November 30, 2022
#
#                                            OrgFullName   OrgClass  \
# 0    Fondazione Policlinico Universitario Agostino ...      OTHER
# 1                 Istanbul Medipol University Hospital      OTHER
# 2            China Academy of Chinese Medical Sciences      OTHER
# 3    Gaziosmanpasa Taksim Research and Education Ho...  OTHER_GOV
# 4    Cambridge University Hospitals NHS Foundation ...      OTHER
# ..                                                 ...        ...
# 869                           University of Pittsburgh      OTHER
# 870                  Spaulding Rehabilitation Hospital      OTHER
# 871                University of Alabama at Birmingham      OTHER
# 872                            Northwestern University      OTHER
# 873                            University of Cambridge      OTHER
#
#                                                Keyword  \
# 0    Early -Warning Scores, NEWS, NEWS2, qSOFA, REM...
# 1                            exercise, videoconference
# 2
# 3                           covid-19, NİCaS, pneumonia
# 4
# ..                                                 ...
# 869
# 870  Home cooking, Telemedicine, Nutrition, Health ...
# 871                      Adolescents, Zambia, Football
# 872
# 873  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                        LocationFacility  \
# 0
# 1                            Recruiting
# 2
# 3                            Recruiting
# 4    Recruiting, Recruiting, Recruiting
# ..                                  ...
# 869                          Recruiting
# 870               Completed, Recruiting
# 871                          Recruiting
# 872                          Recruiting
# 873
#
#                              LocationStatus                LocationCity  \
# 0                                                                  Roma
# 1                                Recruiting                    İstanbul
# 2                                            Wuhan, Wuhan, Wuhan, Wuhan
# 3                                Recruiting                    Istanbul
# 4    Recruiting', 'Recruiting', 'Recruiting    Cambridge, London, Truro
# ..                                      ...                         ...
# 869                              Recruiting                  Pittsburgh
# 870                 Completed', 'Recruiting      Charlestown, Ramat Gan
# 871                              Recruiting                      Lusaka
# 872                              Recruiting                     Chicago
# 873                                                           Cambridge
#
#                                     LocationCountry  EnrollmentCount  \
# 0                                             Italy            300.0
# 1                                            Turkey             34.0
# 2                        China, China, China, China            116.0
# 3                                            Turkey             52.0
# 4    United Kingdom, United Kingdom, United Kingdom             90.0
# ..                                              ...              ...
# 869                                   United States            112.0
# 870                           United States, Israel             78.0
# 871                                          Zambia           3200.0
# 872                                   United States            400.0
# 873                                  United Kingdom             44.0
#
#                         StdAge  Gender
# 0           Adult, Older Adult     All
# 1           Adult, Older Adult     All
# 2           Adult, Older Adult     All
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 869         Adult, Older Adult     All
# 870         Adult, Older Adult     All
# 871  Child, Adult, Older Adult  Female
# 872               Child, Adult  Female
# 873         Adult, Older Adult     All
#
# [874 rows x 16 columns]

# %%
clean3.dtypes
# Out:
# Rank                   object
# NCTId                  object
# BriefTitle             object
# StatusVerifiedDate     object
# StartDate              object
# CompletionDate         object
# OrgFullName            object
# OrgClass               object
# Keyword                object
# LocationFacility       object
# LocationStatus         object
# LocationCity           object
# LocationCountry        object
# EnrollmentCount       float64
# StdAge                 object
# Gender                 object
# dtype: object

# %%
clean_Q1_tempDF2 = change_remove45(Q1_tempDF2)
clean_Q1_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04418609  Neuro-COVID-19: Neurological Complications of ...
# 1    1002  NCT04346043  To Access the Egyptian COVID-19 Whole Genome b...
# 2    1003  NCT04360980  The Effects of Standard Protocol With or Witho...
# 3    1004  NCT04391712  Cold Laser Therapy for COVID-19 Positive Patie...
# 4    1005  NCT04345848  Preventing COVID-19 Complications With Low- an...
# ..    ...          ...                                                ...
# 995  1996  NCT04412278  Impact of COVID-19 Pandemic on Perceived Exerc...
# 996  1997  NCT04346927  Telerehabilitation for Patients Diagnosed With...
# 997  1998  NCT04377100  Impact on Anxiety and Motivation of COVID-19 a...
# 998  1999  NCT04379245  COVID-19 Infection in Patients Infected With H...
# 999  2000  NCT04445246  Inhaled Iloprost for Suspected COVID-19 Respir...
#
#     StatusVerifiedDate        StartDate     CompletionDate  \
# 0            June 2020      May 1, 2020       May 30, 2022
# 1           April 2020   April 20, 2020   December 1, 2020
# 2           April 2020   March 20, 2020       May 30, 2020
# 3             May 2020   April 30, 2020      June 30, 2020
# 4           April 2020   April 28, 2020  November 30, 2020
# ..                 ...              ...                ...
# 995          June 2020     June 1, 2020       June 8, 2020
# 996          July 2020  August 10, 2020  November 30, 2020
# 997       July 9, 2020    July 28, 2020  February 28, 2021
# 998           May 2020   April 30, 2020        May 4, 2020
# 999           May 2020     May 23, 2020       May 31, 2021
#
#                                            OrgFullName  OrgClass  \
# 0                                 University of Zurich     OTHER
# 1                                 Ain Shams University     OTHER
# 2       Shahid Beheshti University of Medical Sciences     OTHER
# 3                              Lowell General Hospital     OTHER
# 4                          University Hospital, Geneva     OTHER
# ..                                                 ...       ...
# 995                                    Okan University     OTHER
# 996                                 Istinye University     OTHER
# 997  National Institutes of Health Clinical Center ...       NIH
# 998                            Hospices Civils de Lyon     OTHER
# 999                          Hamad Medical Corporation  INDUSTRY
#
#                                                Keyword  \
# 0
# 1                                                Egypt
# 2
# 3                              COVID, Laser, Pulmonary
# 4                 anticoagulation, heparin, thrombosis
# ..                                                 ...
# 995  Covid 19, Physical activity level, Exercise be...
# 996        Exercise, Breathing exercise, physiotherapy
# 997  Coronavirus, Pandemic, Environmental Stress, A...
# 998
# 999  Iloprost, prostacyclins, inhaled nitric oxide,...
#
#            LocationFacility            LocationStatus    LocationCity  \
# 0                Recruiting                Recruiting          Zürich
# 1                                                               Cairo
# 2    Recruiting, Recruiting  Recruiting', 'Recruiting  Tehran, Tehran
# 3                Recruiting                Recruiting          Lowell
# 4                Recruiting                Recruiting          Geneva
# ..                      ...                       ...             ...
# 995                                                          Istanbul
# 996
# 997              Recruiting                Recruiting        Bethesda
# 998                                                              Lyon
# 999              Recruiting                Recruiting            Doha
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                          Switzerland             30.0
# 1                                                Egypt            100.0
# 2    Iran, Islamic Republic of, Iran, Islamic Repub...             80.0
# 3                                        United States             20.0
# 4                                          Switzerland            200.0
# ..                                                 ...              ...
# 995                                             Turkey            392.0
# 996                                                                30.0
# 997                                      United States            750.0
# 998                                             France           4200.0
# 999                                              Qatar             40.0
#
#                         StdAge Gender
# 0           Adult, Older Adult    All
# 1           Adult, Older Adult    All
# 2           Adult, Older Adult    All
# 3           Adult, Older Adult    All
# 4           Adult, Older Adult    All
# ..                         ...    ...
# 995  Child, Adult, Older Adult    All
# 996         Adult, Older Adult    All
# 997         Adult, Older Adult    All
# 998         Adult, Older Adult    All
# 999         Adult, Older Adult    All
#
# [1000 rows x 16 columns]

# %%
clean_Q1_tempDF1 = change_remove45(Q1_tempDF1)
clean_Q1_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1       2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 4       5  NCT04412265          Frailty in Elderly Patients With COVID-19
# ..    ...          ...                                                ...
# 995   996  NCT04392531  Clinical Trial to Assess Efficacy of cYclospor...
# 996   997  NCT04424771  Post-traumatic Stress Disease in Health Worker...
# 997   998  NCT04361214              Leflunomide in Mild COVID-19 Patients
# 998   999  NCT04418609  Neuro-COVID-19: Neurological Complications of ...
# 999  1000  NCT04401540     Characteristics of Neonatal Covid-19 in Turkey
#
#     StatusVerifiedDate       StartDate     CompletionDate  \
# 0            June 2020     May 5, 2020           May 2021
# 1             May 2020  April 15, 2020   October 15, 2020
# 2            July 2020  September 2020          June 2022
# 3           April 2020  April 27, 2020       October 2020
# 4            June 2020   March 1, 2020      March 1, 2021
# ..                 ...             ...                ...
# 995           May 2020  April 16, 2020          July 2020
# 996          June 2020   March 1, 2020       July 1, 2020
# 997           May 2020     May 5, 2020          July 2020
# 998          June 2020     May 1, 2020       May 30, 2022
# 999          July 2020     May 1, 2020  December 30, 2020
#
#                                            OrgFullName OrgClass  \
# 0               "Centre Hospitalier Régional dOrléans"    OTHER
# 1                         University of Milano Bicocca    OTHER
# 2                              Meharry Medical College    OTHER
# 3             Centre Hospitalier Universitaire, Amiens    OTHER
# 4                         University of Milano Bicocca    OTHER
# ..                                                 ...      ...
# 995  Instituto de Investigación Sanitaria de la Fun...    OTHER
# 996                   Ospedale Policlinico San Martino    OTHER
# 997                              University of Chicago    OTHER
# 998                               University of Zurich    OTHER
# 999  Recep Tayyip Erdogan University Training and R...    OTHER
#
#                                                Keyword  \
# 0    Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1     Lung injury, sars-covid-2, coronavirus infection
# 2    COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3    Hepatocellular Carcinoma, COVID-19, Coronaviru...
# 4    Coronavirus, sars-covid-2, coronavirus infecti...
# ..                                                 ...
# 995
# 996                                           COVID-19
# 997                                        leflunomide
# 998
# 999                              Vertical Transmission
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1    Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995  Recruiting, Recruiting, Recruiting, Recruiting...
# 996                             Recruiting, Recruiting
# 997                                         Recruiting
# 998                                         Recruiting
# 999                                         Recruiting
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 996                           Recruiting', 'Recruiting
# 997                                         Recruiting
# 998                                         Recruiting
# 999                                         Recruiting
#
#                                           LocationCity  \
# 0                                              Orléans
# 1    Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                            Nashville
# 3                                               Amiens
# 4                                                Monza
# ..                                                 ...
# 995  La Coruña, La Coruña, Mostoles, Valdemoro, Vil...
# 996                                    Brindisi, Genoa
# 997                                            Chicago
# 998                                             Zürich
# 999                                               Rize
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                               France             50.0
# 1    Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                        United States            200.0
# 3                                               France             50.0
# 4                                                Italy            300.0
# ..                                                 ...              ...
# 995    Spain, Spain, Spain, Spain, Spain, Spain, Spain            120.0
# 996                                       Italy, Italy            800.0
# 997                                      United States             20.0
# 998                                        Switzerland             30.0
# 999                                             Turkey             90.0
#
#                  StdAge  Gender
# 0                 Adult  Female
# 1    Adult, Older Adult     All
# 2                 Adult  Female
# 3    Adult, Older Adult     All
# 4    Adult, Older Adult     All
# ..                  ...     ...
# 995  Adult, Older Adult     All
# 996  Adult, Older Adult     All
# 997  Adult, Older Adult     All
# 998  Adult, Older Adult     All
# 999               Child     All
#
# [1000 rows x 16 columns]

# %%
query = 'coronavirus'
quest2URL = f'http://ClinicalTrials.gov/api/query/study_fields?expr={query}\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest2 = requests.get(quest2URL).json()
Quest2
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:24 00:13:26.663',
#   'Expression': 'coronavirus',
#   'NStudiesAvail': 346767,
#   'NStudiesFound': 1458,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'StartDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationFacility',
#    'LocationStatus',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04279795'],
#     'BriefTitle': ['Detection of 2019 Novel Coronavirus in Multiple Organ System and Its Relationship With Clinical Manifestations'],
#     'StatusVerifiedDate': ['February 2020'],
#     'StartDate': ['January 20, 2020'],
#     'CompletionDate': ['February 28, 2021'],
#     'OrgFullName': ['Third Affiliated Hospital, Sun Yat-Sen University'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['2019 Novel Coronavirus'],
#     'LocationFacility': ['The Third Affiliated Hospital of Sun Yat-sen University'],
#     'LocationStatus': ['Recruiting'],
#     'LocationCity': ['Guangzhou'],
#     'LocationCountry': ['China'],
#     'EnrollmentCount': ['20'],
#     'StdAge': ['Child', 'Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
limit2 = Quest2['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit2
# Out:
# 1458

# %%
tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   

tempL1 = requests.get(tempURL1).json()

tempURL2 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk={limit2}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

Q2_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q2_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']

# %%
Q2_tempDF1 = pd.DataFrame(Q2_tempL1)
Q2_tempDF2 = pd.DataFrame(Q2_tempL2)

# %%
clean_Q2_tempDF1 = change_remove45(Q2_tempDF1)
clean_Q2_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 1       2  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4       5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ..    ...          ...                                                ...
# 995   996  NCT04391920  Registry of CytoSorb Therapy in COVID-19 ICU P...
# 996   997  NCT04431869  In-Utero Vascular Accidents in Neonates From C...
# 997   998  NCT04466670  Hemostasis in COVID-19: an Adaptive Clinical T...
# 998   999  NCT04402905  Observational Study in Diagnosed Patients COVI...
# 999  1000  NCT04348240  Transmissibility and Viral Load of SARS-CoV-2 ...
#
#     StatusVerifiedDate       StartDate      CompletionDate  \
# 0             May 2020  April 15, 2020    October 15, 2020
# 1            June 2020     May 5, 2020            May 2021
# 2            July 2020  September 2020           June 2022
# 3            June 2020   March 1, 2020       March 1, 2021
# 4            June 2020    May 15, 2020  September 30, 2020
# ..                 ...             ...                 ...
# 995           May 2020        May 2020         August 2021
# 996          June 2020       July 2020           July 2022
# 997          July 2020    July 8, 2020      April 30, 2021
# 998           May 2020   June 15, 2020     August 15, 2020
# 999       May 18, 2020  April 16, 2020        July 1, 2021
#
#                                            OrgFullName  OrgClass  \
# 0                         University of Milano Bicocca     OTHER
# 1               "Centre Hospitalier Régional dOrléans"     OTHER
# 2                              Meharry Medical College     OTHER
# 3                         University of Milano Bicocca     OTHER
# 4                         University of Milano Bicocca     OTHER
# ..                                                 ...       ...
# 995                                  CytoSorbents, Inc  INDUSTRY
# 996                     University of Colorado, Denver     OTHER
# 997           University of Sao Paulo General Hospital     OTHER
# 998  "Centre de Recherches et dEtude sur la Patholo...     OTHER
# 999  National Institutes of Health Clinical Center ...       NIH
#
#                                                Keyword  \
# 0     Lung injury, sars-covid-2, coronavirus infection
# 1    Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 2    COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3    Coronavirus, sars-covid-2, coronavirus infecti...
# 4     Coronavirus, sars-covid-2, coronavirus infection
# ..                                                 ...
# 995
# 996
# 997  SARS-CoV-2, Thrombosis, Coagulopathy, Anticoag...
# 998
# 999  Saliva, Coronavirus, SARS-CoV-2, Symptoms, COV...
#
#                                       LocationFacility  \
# 0    Recruiting, Recruiting, Recruiting, Recruiting...
# 1                                           Recruiting
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995
# 996
# 997                                         Recruiting
# 998
# 999                                         Recruiting
#
#                                         LocationStatus  \
# 0    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 1                                           Recruiting
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995
# 996
# 997                                         Recruiting
# 998
# 999                                         Recruiting
#
#                                           LocationCity  \
# 0    Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 1                                              Orléans
# 2                                            Nashville
# 3                                                Monza
# 4                                                Monza
# ..                                                 ...
# 995
# 996                                             Aurora
# 997                                          Sao Paulo
# 998                                              Paris
# 999                                           Bethesda
#
#                                        LocationCountry  EnrollmentCount  \
# 0    Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 1                                               France             50.0
# 2                                        United States            200.0
# 3                                                Italy            300.0
# 4                                                Italy            500.0
# ..                                                 ...              ...
# 995                                                              1000.0
# 996                                      United States            200.0
# 997                                             Brazil            310.0
# 998                                             France            450.0
# 999                                      United States             60.0
#
#                  StdAge  Gender
# 0    Adult, Older Adult     All
# 1                 Adult  Female
# 2                 Adult  Female
# 3    Adult, Older Adult     All
# 4    Adult, Older Adult     All
# ..                  ...     ...
# 995  Adult, Older Adult     All
# 996  Adult, Older Adult     All
# 997  Adult, Older Adult     All
# 998  Adult, Older Adult     All
# 999  Adult, Older Adult     All
#
# [1000 rows x 16 columns]

# %%
clean_Q2_tempDF2 = change_remove45(Q2_tempDF2)
clean_Q2_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04418609  Neuro-COVID-19: Neurological Complications of ...
# 1    1002  NCT04346043  To Access the Egyptian COVID-19 Whole Genome b...
# 2    1003  NCT04360980  The Effects of Standard Protocol With or Witho...
# 3    1004  NCT04391712  Cold Laser Therapy for COVID-19 Positive Patie...
# 4    1005  NCT04345848  Preventing COVID-19 Complications With Low- an...
# ..    ...          ...                                                ...
# 453  1454  NCT04455815  A Trial Looking at the Use of Camostat to Redu...
# 454  1455  NCT04305106  Bevacizumab in Severe or Critically Severe Pat...
# 455  1456  NCT04341675  Sirolimus Treatment in Hospitalized Patients W...
# 456  1457  NCT04344938  Covid 19 Pandemic. Emerging Legal and Ehical D...
# 457  1458  NCT04444115  Loneliness During Strict and Lifted Social Dis...
#
#     StatusVerifiedDate       StartDate     CompletionDate  \
# 0            June 2020     May 1, 2020       May 30, 2022
# 1           April 2020  April 20, 2020   December 1, 2020
# 2           April 2020  March 20, 2020       May 30, 2020
# 3             May 2020  April 30, 2020      June 30, 2020
# 4           April 2020  April 28, 2020  November 30, 2020
# ..                 ...             ...                ...
# 453          July 2020   July 27, 2020    August 31, 2021
# 454         March 2020  March 17, 2020      July 31, 2020
# 455           May 2020  April 24, 2020     September 2020
# 456         April 2020      April 2020          July 2020
# 457          June 2020   June 22, 2020      July 13, 2020
#
#                                         OrgFullName OrgClass  \
# 0                              University of Zurich    OTHER
# 1                              Ain Shams University    OTHER
# 2    Shahid Beheshti University of Medical Sciences    OTHER
# 3                           Lowell General Hospital    OTHER
# 4                       University Hospital, Geneva    OTHER
# ..                                              ...      ...
# 453                              Cancer Research UK    OTHER
# 454            Qilu Hospital of Shandong University    OTHER
# 455                        University of Cincinnati    OTHER
# 456                               Assiut University    OTHER
# 457                                       Modum Bad    OTHER
#
#                                                Keyword  \
# 0
# 1                                                Egypt
# 2
# 3                              COVID, Laser, Pulmonary
# 4                 anticoagulation, heparin, thrombosis
# ..                                                 ...
# 453
# 454
# 455
# 456
# 457  COVID-19, social distancing, loneliness, worry...
#
#                        LocationFacility                        LocationStatus  \
# 0                            Recruiting                            Recruiting
# 1
# 2                Recruiting, Recruiting              Recruiting', 'Recruiting
# 3                            Recruiting                            Recruiting
# 4                            Recruiting                            Recruiting
# ..                                  ...                                   ...
# 453
# 454                          Recruiting                            Recruiting
# 455  Active, not recruiting, Recruiting  Active, not recruiting', 'Recruiting
# 456
# 457
#
#             LocationCity                                    LocationCountry  \
# 0                 Zürich                                        Switzerland
# 1                  Cairo                                              Egypt
# 2         Tehran, Tehran  Iran, Islamic Republic of, Iran, Islamic Repub...
# 3                 Lowell                                      United States
# 4                 Geneva                                        Switzerland
# ..                   ...                                                ...
# 453    Edinburgh, Oxford                     United Kingdom, United Kingdom
# 454                Jinan                                              China
# 455  Chicago, Cincinnati                       United States, United States
# 456
# 457
#
#      EnrollmentCount              StdAge Gender
# 0               30.0  Adult, Older Adult    All
# 1              100.0  Adult, Older Adult    All
# 2               80.0  Adult, Older Adult    All
# 3               20.0  Adult, Older Adult    All
# 4              200.0  Adult, Older Adult    All
# ..               ...                 ...    ...
# 453            389.0  Adult, Older Adult    All
# 454            140.0  Adult, Older Adult    All
# 455             30.0  Adult, Older Adult    All
# 456            874.0               Adult    All
# 457          10084.0  Adult, Older Adult    All
#
# [458 rows x 16 columns]

# %%
DF_QQ = pd.concat([clean_Q1_tempDF1, clean_Q1_tempDF2, clean_Q1_tempDF3, clean_Q2_tempDF1, clean_Q2_tempDF2], ignore_index=True)
DF_QQ = DF_QQ.drop_duplicates()
DF_QQ
# Out:
#       Rank        NCTId                                         BriefTitle  \
# 0        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2        3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3        4  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 4        5  NCT04412265          Frailty in Elderly Patients With COVID-19
# ...    ...          ...                                                ...
# 3869   996  NCT04391920  Registry of CytoSorb Therapy in COVID-19 ICU P...
# 3870   997  NCT04431869  In-Utero Vascular Accidents in Neonates From C...
# 3871   998  NCT04466670  Hemostasis in COVID-19: an Adaptive Clinical T...
# 3872   999  NCT04402905  Observational Study in Diagnosed Patients COVI...
# 3873  1000  NCT04348240  Transmissibility and Viral Load of SARS-CoV-2 ...
#
#      StatusVerifiedDate       StartDate    CompletionDate  \
# 0             June 2020     May 5, 2020          May 2021
# 1              May 2020  April 15, 2020  October 15, 2020
# 2             July 2020  September 2020         June 2022
# 3            April 2020  April 27, 2020      October 2020
# 4             June 2020   March 1, 2020     March 1, 2021
# ...                 ...             ...               ...
# 3869           May 2020        May 2020       August 2021
# 3870          June 2020       July 2020         July 2022
# 3871          July 2020    July 8, 2020    April 30, 2021
# 3872           May 2020   June 15, 2020   August 15, 2020
# 3873       May 18, 2020  April 16, 2020      July 1, 2021
#
#                                             OrgFullName  OrgClass  \
# 0                "Centre Hospitalier Régional dOrléans"     OTHER
# 1                          University of Milano Bicocca     OTHER
# 2                               Meharry Medical College     OTHER
# 3              Centre Hospitalier Universitaire, Amiens     OTHER
# 4                          University of Milano Bicocca     OTHER
# ...                                                 ...       ...
# 3869                                  CytoSorbents, Inc  INDUSTRY
# 3870                     University of Colorado, Denver     OTHER
# 3871           University of Sao Paulo General Hospital     OTHER
# 3872  "Centre de Recherches et dEtude sur la Patholo...     OTHER
# 3873  National Institutes of Health Clinical Center ...       NIH
#
#                                                 Keyword  \
# 0     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1      Lung injury, sars-covid-2, coronavirus infection
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Hepatocellular Carcinoma, COVID-19, Coronaviru...
# 4     Coronavirus, sars-covid-2, coronavirus infecti...
# ...                                                 ...
# 3869
# 3870
# 3871  SARS-CoV-2, Thrombosis, Coagulopathy, Anticoag...
# 3872
# 3873  Saliva, Coronavirus, SARS-CoV-2, Symptoms, COV...
#
#                                        LocationFacility  \
# 0                                            Recruiting
# 1     Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3869
# 3870
# 3871                                         Recruiting
# 3872
# 3873                                         Recruiting
#
#                                          LocationStatus  \
# 0                                            Recruiting
# 1     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3869
# 3870
# 3871                                         Recruiting
# 3872
# 3873                                         Recruiting
#
#                                            LocationCity  \
# 0                                               Orléans
# 1     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                             Nashville
# 3                                                Amiens
# 4                                                 Monza
# ...                                                 ...
# 3869
# 3870                                             Aurora
# 3871                                          Sao Paulo
# 3872                                              Paris
# 3873                                           Bethesda
#
#                                         LocationCountry  EnrollmentCount  \
# 0                                                France             50.0
# 1     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                         United States            200.0
# 3                                                France             50.0
# 4                                                 Italy            300.0
# ...                                                 ...              ...
# 3869                                                              1000.0
# 3870                                      United States            200.0
# 3871                                             Brazil            310.0
# 3872                                             France            450.0
# 3873                                      United States             60.0
#
#                   StdAge  Gender
# 0                  Adult  Female
# 1     Adult, Older Adult     All
# 2                  Adult  Female
# 3     Adult, Older Adult     All
# 4     Adult, Older Adult     All
# ...                  ...     ...
# 3869  Adult, Older Adult     All
# 3870  Adult, Older Adult     All
# 3871  Adult, Older Adult     All
# 3872  Adult, Older Adult     All
# 3873  Adult, Older Adult     All
#
# [3871 rows x 16 columns]

# %%
dups_color = DF_QQ.pivot_table(index=['NCTId'], aggfunc='size')
print (dups_color)
# Out:
# NCTId
# NCT01306084    1
# NCT02517489    1
# NCT02656381    1
# NCT02735707    1
# NCT02765191    1
#               ..
# NCT04486404    1
# NCT04486417    1
# NCT04486482    1
# NCT04486508    1
# NCT04486521    1
# Length: 2823, dtype: int64

# %%
df_final = DF_QQ.drop_duplicates(subset='NCTId', keep="first")
df_final
# Out:
#       Rank        NCTId                                         BriefTitle  \
# 0        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2        3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3        4  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 4        5  NCT04412265          Frailty in Elderly Patients With COVID-19
# ...    ...          ...                                                ...
# 2869  2870  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 2870  2871  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 2871  2872  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 2872  2873  NCT03922334                        Navigating New Motherhood 2
# 2873  2874  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#      StatusVerifiedDate         StartDate     CompletionDate  \
# 0             June 2020       May 5, 2020           May 2021
# 1              May 2020    April 15, 2020   October 15, 2020
# 2             July 2020    September 2020          June 2022
# 3            April 2020    April 27, 2020       October 2020
# 4             June 2020     March 1, 2020      March 1, 2021
# ...                 ...               ...                ...
# 2869          June 2020    March 25, 2019      April 8, 2022
# 2870           May 2020      May 20, 2019      February 2022
# 2871          June 2020     March 1, 2020      June 30, 2023
# 2872          June 2020  January 21, 2020      December 2024
# 2873          June 2020   August 31, 2020  November 30, 2022
#
#                                    OrgFullName OrgClass  \
# 0       "Centre Hospitalier Régional dOrléans"    OTHER
# 1                 University of Milano Bicocca    OTHER
# 2                      Meharry Medical College    OTHER
# 3     Centre Hospitalier Universitaire, Amiens    OTHER
# 4                 University of Milano Bicocca    OTHER
# ...                                        ...      ...
# 2869                  University of Pittsburgh    OTHER
# 2870         Spaulding Rehabilitation Hospital    OTHER
# 2871       University of Alabama at Birmingham    OTHER
# 2872                   Northwestern University    OTHER
# 2873                   University of Cambridge    OTHER
#
#                                                 Keyword  \
# 0     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1      Lung injury, sars-covid-2, coronavirus infection
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Hepatocellular Carcinoma, COVID-19, Coronaviru...
# 4     Coronavirus, sars-covid-2, coronavirus infecti...
# ...                                                 ...
# 2869
# 2870  Home cooking, Telemedicine, Nutrition, Health ...
# 2871                      Adolescents, Zambia, Football
# 2872
# 2873  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                                        LocationFacility  \
# 0                                            Recruiting
# 1     Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 2869                                         Recruiting
# 2870                              Completed, Recruiting
# 2871                                         Recruiting
# 2872                                         Recruiting
# 2873
#
#                                          LocationStatus  \
# 0                                            Recruiting
# 1     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 2869                                         Recruiting
# 2870                            Completed', 'Recruiting
# 2871                                         Recruiting
# 2872                                         Recruiting
# 2873
#
#                                            LocationCity  \
# 0                                               Orléans
# 1     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                             Nashville
# 3                                                Amiens
# 4                                                 Monza
# ...                                                 ...
# 2869                                         Pittsburgh
# 2870                             Charlestown, Ramat Gan
# 2871                                             Lusaka
# 2872                                            Chicago
# 2873                                          Cambridge
#
#                                         LocationCountry  EnrollmentCount  \
# 0                                                France             50.0
# 1     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                         United States            200.0
# 3                                                France             50.0
# 4                                                 Italy            300.0
# ...                                                 ...              ...
# 2869                                      United States            112.0
# 2870                              United States, Israel             78.0
# 2871                                             Zambia           3200.0
# 2872                                      United States            400.0
# 2873                                     United Kingdom             44.0
#
#                          StdAge  Gender
# 0                         Adult  Female
# 1            Adult, Older Adult     All
# 2                         Adult  Female
# 3            Adult, Older Adult     All
# 4            Adult, Older Adult     All
# ...                         ...     ...
# 2869         Adult, Older Adult     All
# 2870         Adult, Older Adult     All
# 2871  Child, Adult, Older Adult  Female
# 2872               Child, Adult  Female
# 2873         Adult, Older Adult     All
#
# [2823 rows x 16 columns]

# %%
df_final.set_index('NCTId', inplace=True)
df_final
# Out:
#              Rank                                         BriefTitle  \
# NCTId
# NCT04395924     1         Maternal-foetal Transmission of SARS-Cov-2
# NCT04395482     2  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# NCT04476940     3  COVID-19 Breastfeeding Guideline for African-A...
# NCT04367805     4  COVID-19 Infection in Patients With Hepatocell...
# NCT04412265     5          Frailty in Elderly Patients With COVID-19
# ...           ...                                                ...
# NCT03728257  2870  Lung Transplant G0 (LTGO): Improving Self-Mana...
# NCT03823469  2871  Evaluating the Impact of a Culinary Coaching T...
# NCT04429061  2872  Reaching 90 90 90 in Adolescents in Zambia: Us...
# NCT03922334  2873                        Navigating New Motherhood 2
# NCT04180709  2874  CBT to Reduce Insomnia and Improve Social Reco...
#
#             StatusVerifiedDate         StartDate     CompletionDate  \
# NCTId
# NCT04395924          June 2020       May 5, 2020           May 2021
# NCT04395482           May 2020    April 15, 2020   October 15, 2020
# NCT04476940          July 2020    September 2020          June 2022
# NCT04367805         April 2020    April 27, 2020       October 2020
# NCT04412265          June 2020     March 1, 2020      March 1, 2021
# ...                        ...               ...                ...
# NCT03728257          June 2020    March 25, 2019      April 8, 2022
# NCT03823469           May 2020      May 20, 2019      February 2022
# NCT04429061          June 2020     March 1, 2020      June 30, 2023
# NCT03922334          June 2020  January 21, 2020      December 2024
# NCT04180709          June 2020   August 31, 2020  November 30, 2022
#
#                                           OrgFullName OrgClass  \
# NCTId
# NCT04395924    "Centre Hospitalier Régional dOrléans"    OTHER
# NCT04395482              University of Milano Bicocca    OTHER
# NCT04476940                   Meharry Medical College    OTHER
# NCT04367805  Centre Hospitalier Universitaire, Amiens    OTHER
# NCT04412265              University of Milano Bicocca    OTHER
# ...                                               ...      ...
# NCT03728257                  University of Pittsburgh    OTHER
# NCT03823469         Spaulding Rehabilitation Hospital    OTHER
# NCT04429061       University of Alabama at Birmingham    OTHER
# NCT03922334                   Northwestern University    OTHER
# NCT04180709                   University of Cambridge    OTHER
#
#                                                        Keyword  \
# NCTId
# NCT04395924  Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# NCT04395482   Lung injury, sars-covid-2, coronavirus infection
# NCT04476940  COVID-19, Exclusive Breastfeeding, Breastfeedi...
# NCT04367805  Hepatocellular Carcinoma, COVID-19, Coronaviru...
# NCT04412265  Coronavirus, sars-covid-2, coronavirus infecti...
# ...                                                        ...
# NCT03728257
# NCT03823469  Home cooking, Telemedicine, Nutrition, Health ...
# NCT04429061                      Adolescents, Zambia, Football
# NCT03922334
# NCT04180709  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                                               LocationFacility  \
# NCTId
# NCT04395924                                         Recruiting
# NCT04395482  Recruiting, Recruiting, Recruiting, Recruiting...
# NCT04476940
# NCT04367805                                         Recruiting
# NCT04412265                                         Recruiting
# ...                                                        ...
# NCT03728257                                         Recruiting
# NCT03823469                              Completed, Recruiting
# NCT04429061                                         Recruiting
# NCT03922334                                         Recruiting
# NCT04180709
#
#                                                 LocationStatus  \
# NCTId
# NCT04395924                                         Recruiting
# NCT04395482  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# NCT04476940
# NCT04367805                                         Recruiting
# NCT04412265                                         Recruiting
# ...                                                        ...
# NCT03728257                                         Recruiting
# NCT03823469                            Completed', 'Recruiting
# NCT04429061                                         Recruiting
# NCT03922334                                         Recruiting
# NCT04180709
#
#                                                   LocationCity  \
# NCTId
# NCT04395924                                            Orléans
# NCT04395482  Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# NCT04476940                                          Nashville
# NCT04367805                                             Amiens
# NCT04412265                                              Monza
# ...                                                        ...
# NCT03728257                                         Pittsburgh
# NCT03823469                             Charlestown, Ramat Gan
# NCT04429061                                             Lusaka
# NCT03922334                                            Chicago
# NCT04180709                                          Cambridge
#
#                                                LocationCountry  \
# NCTId
# NCT04395924                                             France
# NCT04395482  Italy, Italy, Italy, Italy, Italy, Italy, Ital...
# NCT04476940                                      United States
# NCT04367805                                             France
# NCT04412265                                              Italy
# ...                                                        ...
# NCT03728257                                      United States
# NCT03823469                              United States, Israel
# NCT04429061                                             Zambia
# NCT03922334                                      United States
# NCT04180709                                     United Kingdom
#
#              EnrollmentCount                     StdAge  Gender
# NCTId
# NCT04395924             50.0                      Adult  Female
# NCT04395482            500.0         Adult, Older Adult     All
# NCT04476940            200.0                      Adult  Female
# NCT04367805             50.0         Adult, Older Adult     All
# NCT04412265            300.0         Adult, Older Adult     All
# ...                      ...                        ...     ...
# NCT03728257            112.0         Adult, Older Adult     All
# NCT03823469             78.0         Adult, Older Adult     All
# NCT04429061           3200.0  Child, Adult, Older Adult  Female
# NCT03922334            400.0               Child, Adult  Female
# NCT04180709             44.0         Adult, Older Adult     All
#
# [2823 rows x 15 columns]
