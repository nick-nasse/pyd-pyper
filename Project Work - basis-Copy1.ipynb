# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
questURL = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest = requests.get(questURL).json()
Quest
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:24 00:13:26.663',
#   'Expression': 'covid 19',
#   'NStudiesAvail': 346767,
#   'NStudiesFound': 2874,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04395482'],
#     'BriefTitle': ['Lung CT Scan Analysis of SARS-CoV2 Induced Lung Injury'],
#     'StatusVerifiedDate': ['May 2020'],
#     'CompletionDate': ['October 15, 2020'],
#     'OrgFullName': ['University of Milano Bicocca'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['Lung injury', 'sars-covid-2', 'coronavirus infection'],
#     'LocationCity': ['Bergamo',
#      'Bergamo',
#      'Ferrara',
#      'Lecco',
#      'Melzo',
#      'Monza',
#      'Rimini',
#      'San Marino'],
#     'LocationCountry': ['Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'San Marino'],
#     'EnrollmentCount': ['500'],
#     'StdAge': ['Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
limit1 = Quest['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit1
# Out:
# 2874

# %%
# Query the api in packets of 1000 then merge into a single dataframe

tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   
tempL1 = requests.get(tempURL1).json()

tempURL2 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk=2000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

tempURL3 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=2001\
           &max_rnk={limit1}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL3 = requests.get(tempURL3).json()

Q1_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q1_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']
Q1_tempL3 = tempL3['StudyFieldsResponse']['StudyFields']

# %%
Q1_tempDF1 = pd.DataFrame(Q1_tempL1)
Q1_tempDF2 = pd.DataFrame(Q1_tempL2)
Q1_tempDF3 = pd.DataFrame(Q1_tempL3)

# %%
#returns single list of col values from all 3 temp DF's 

def unListItems(col):
    lst_1 = [' ']*len(Q1_tempDF1[col])  # create empty list the length of 'Q1_tempDF1[col]'
    i = 0
    while i < len(Q1_tempDF1[col]):
        if len(Q1_tempDF1[col][i])==0:
            lst_1[i] = None
        else:
            lst_1[i] = Q1_tempDF1[col][i][0]
        i += 1
    lst_2 = [' ']*len(Q1_tempDF2[col])
    i = 0
    while i < len(Q1_tempDF2[col]):
        if len(Q1_tempDF2[col][i])==0:
            lst_2[i] = None
        else:
            lst_2[i] = Q1_tempDF2[col][i][0]
        i += 1      
    lst_3 = [' ']*len(Q1_tempDF3[col])
    i = 0
    while i < len(Q1_tempDF3[col]):
        if len(Q1_tempDF3[col][i])==0:
            lst_3[i] = None
        else:
            lst_3[i] = Q1_tempDF3[col][i][0]
        i += 1
    LIST = lst_1 + lst_2 + lst_3
    return LIST

# %%
Q1_tempDF3
# Out:
#      Rank          NCTId                                         BriefTitle  \
# 0    2001  [NCT04412330]  [Optimizing Outcomes With Physical Therapy Tre...
# 1    2002  [NCT04372680]  [WeanINg From Mechanical Ventilation for ARDS ...
# 2    2003  [NCT04397172]  [Intensive Care Associated Complications and O...
# 3    2004  [NCT04447534]  [Zinc With Chloroquine/Hydroxychloroquine in T...
# 4    2005  [NCT04285190]  [The Effect of T89 on Improving Oxygen Saturat...
# ..    ...            ...                                                ...
# 869  2870  [NCT03728257]  [Lung Transplant G0 (LTGO): Improving Self-Man...
# 870  2871  [NCT03823469]  [Evaluating the Impact of a Culinary Coaching ...
# 871  2872  [NCT04429061]  [Reaching 90 90 90 in Adolescents in Zambia: U...
# 872  2873  [NCT03922334]                      [Navigating New Motherhood 2]
# 873  2874  [NCT04180709]  [CBT to Reduce Insomnia and Improve Social Rec...
#
#     StatusVerifiedDate        CompletionDate  \
# 0          [June 2020]         [May 1, 2021]
# 1         [April 2020]  [September 22, 2020]
# 2           [May 2020]       [December 2021]
# 3          [June 2020]      [August 1, 2020]
# 4         [March 2020]      [April 20, 2020]
# ..                 ...                   ...
# 869        [June 2020]       [April 8, 2022]
# 870         [May 2020]       [February 2022]
# 871        [June 2020]       [June 30, 2023]
# 872        [June 2020]       [December 2024]
# 873        [June 2020]   [November 30, 2022]
#
#                                   OrgFullName    OrgClass  \
# 0                    [University of Kentucky]     [OTHER]
# 1             [University Hospital, Toulouse]     [OTHER]
# 2    [University Hospital Inselspital, Berne]     [OTHER]
# 3                          [Tanta University]     [OTHER]
# 4               [Tasly Pharmaceuticals, Inc.]  [INDUSTRY]
# ..                                        ...         ...
# 869                [University of Pittsburgh]     [OTHER]
# 870       [Spaulding Rehabilitation Hospital]     [OTHER]
# 871     [University of Alabama at Birmingham]     [OTHER]
# 872                 [Northwestern University]     [OTHER]
# 873                 [University of Cambridge]     [OTHER]
#
#                                                Keyword  \
# 0                                                   []
# 1    [COVID-19,, ARDS, Mechanical ventilation, Lung...
# 2                      [Corona, SARS-CoV2, ARDS, PICS]
# 3                                                   []
# 4                                           [COVID-19]
# ..                                                 ...
# 869                                                 []
# 870  [Home cooking, Telemedicine, Nutrition, Health...
# 871                    [Adolescents, Zambia, Football]
# 872                                                 []
# 873  [Cognition, Social Recovery, Immunopsychiatry,...
#
#                  LocationCity          LocationCountry EnrollmentCount  \
# 0                 [Lexington]          [United States]            [20]
# 1         [Limoges, Toulouse]         [France, France]           [200]
# 2                      [Bern]            [Switzerland]            [50]
# 3                     [Tanta]                  [Egypt]           [200]
# 4                          []                       []             [0]
# ..                        ...                      ...             ...
# 869              [Pittsburgh]          [United States]           [112]
# 870  [Charlestown, Ramat Gan]  [United States, Israel]            [78]
# 871                  [Lusaka]                 [Zambia]          [3200]
# 872                 [Chicago]          [United States]           [400]
# 873               [Cambridge]         [United Kingdom]            [44]
#
#                           StdAge    Gender
# 0           [Adult, Older Adult]     [All]
# 1           [Adult, Older Adult]     [All]
# 2           [Adult, Older Adult]     [All]
# 3           [Adult, Older Adult]     [All]
# 4           [Adult, Older Adult]     [All]
# ..                           ...       ...
# 869         [Adult, Older Adult]     [All]
# 870         [Adult, Older Adult]     [All]
# 871  [Child, Adult, Older Adult]  [Female]
# 872               [Child, Adult]  [Female]
# 873         [Adult, Older Adult]     [All]
#
# [874 rows x 13 columns]

# %%
#retrive unListed Items, populate Query1 DataFrame with query results from id, title, and date keys

ID = unListItems('NCTId')
Title = unListItems('BriefTitle')
VerifiedDate = unListItems('StatusVerifiedDate')
CompletionDate = unListItems('CompletionDate')
OrgFullName = unListItems('OrgFullName')
OrgClass = unListItems('OrgClass')
QueryType = ['covid 19']*len(ID)
Country = unListItems('LocationCountry')
City = unListItems('LocationCity')
Participants = unListItems("EnrollmentCount")
Age_Groups = unListItems("StdAge")
Gender = unListItems("Gender")

DF_Q1 = pd.DataFrame()
DF_Q1.insert(0, 'ID', ID)
DF_Q1.insert(1, 'Title', Title)
DF_Q1.insert(2, 'Date Verified', VerifiedDate)
DF_Q1.insert(3, 'Completion Date', CompletionDate)
DF_Q1.insert(4, 'Organization', OrgFullName)
DF_Q1.insert(5, 'Organization Class', OrgClass)
DF_Q1.insert(6, 'Country', Country)
DF_Q1.insert(7, 'City', City)
DF_Q1.insert(8, 'Participants', Participants)
DF_Q1.insert(9, 'Age Groups', Age_Groups)
DF_Q1.insert(10, 'Gender', Gender)

# %%
groupID = DF_Q1.groupby('ID')

# %%
df = pd.DataFrame(groupID.count())

# %%
DF_Q1.loc[DF_Q1['ID']=='NCT04330144']
# Out:
#               ID                                              Title  \
# 907  NCT04330144  Hydroxychloroquine as Post Exposure Prophylaxi...
#
#     Date Verified Completion Date                Organization  \
# 907    March 2020  March 30, 2022  Gangnam Severance Hospital
#
#     Organization Class Country  City Participants Age Groups Gender
# 907              OTHER    None  None         2486      Adult    All

# %%
df = df.loc[df['Title']>1]

# %%
dupeList = []
for i in df.index:
    dupeList.append(i)
print(dupeList)
# Out:
# ['NCT04313127', 'NCT04324606', 'NCT04324866', 'NCT04332016', 'NCT04335084', 'NCT04335188', 'NCT04336761', 'NCT04342884', 'NCT04344379', 'NCT04344548', 'NCT04345601', 'NCT04345848', 'NCT04347512', 'NCT04349618', 'NCT04350086', 'NCT04352959', 'NCT04353271', 'NCT04354428', 'NCT04355429', 'NCT04355494', 'NCT04358588', 'NCT04360759', 'NCT04362969', 'NCT04363541', 'NCT04364737', 'NCT04366154', 'NCT04366167', 'NCT04369469', 'NCT04369794', 'NCT04370119', 'NCT04371354', 'NCT04371471', 'NCT04372680', 'NCT04373811', 'NCT04374461', 'NCT04375397', 'NCT04375670', 'NCT04377503', 'NCT04379297', 'NCT04379544', 'NCT04380779', 'NCT04382131', 'NCT04382196', 'NCT04382391', 'NCT04384731', 'NCT04385121', 'NCT04389671', 'NCT04395768', 'NCT04401202', 'NCT04401527', 'NCT04402905', 'NCT04403100', 'NCT04403438', 'NCT04403906', 'NCT04407273', 'NCT04408040', 'NCT04408365', 'NCT04409327', 'NCT04411511', 'NCT04412018', 'NCT04414410', 'NCT04416308', 'NCT04416399', 'NCT04421391', 'NCT04424901', 'NCT04430062', 'NCT04431869', 'NCT04432350', 'NCT04432922', 'NCT04433949', 'NCT04434157', 'NCT04435314', 'NCT04442087', 'NCT04443140', 'NCT04444531', 'NCT04444609', 'NCT04445220', 'NCT04445246', 'NCT04445285', 'NCT04446169', 'NCT04448782', 'NCT04451317', 'NCT04452422', 'NCT04452487', 'NCT04456010', 'NCT04456426', 'NCT04456556', 'NCT04459689', 'NCT04462120', 'NCT04463004', 'NCT04468009', 'NCT04469634', 'NCT04473547', 'NCT04477993', 'NCT04479150']

# %%
query = 'coronavirus'
quest2URL = f'http://ClinicalTrials.gov/api/query/study_fields?expr={query}\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest2 = requests.get(quest2URL).json()
Quest2
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:24 00:13:26.663',
#   'Expression': 'coronavirus',
#   'NStudiesAvail': 346767,
#   'NStudiesFound': 1458,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04279795'],
#     'BriefTitle': ['Detection of 2019 Novel Coronavirus in Multiple Organ System and Its Relationship With Clinical Manifestations'],
#     'StatusVerifiedDate': ['February 2020'],
#     'CompletionDate': ['February 28, 2021'],
#     'OrgFullName': ['Third Affiliated Hospital, Sun Yat-Sen University'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['2019 Novel Coronavirus'],
#     'LocationCity': ['Guangzhou'],
#     'LocationCountry': ['China'],
#     'EnrollmentCount': ['20'],
#     'StdAge': ['Child', 'Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
limit2 = Quest2['StudyFieldsResponse']['NStudiesFound'] #make sure we don't ask for results outside of the scope of our query
limit2
# Out:
# 1458

# %%
# Query the api in packets of 1000 then merge into a single dataframe

tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   
tempL1 = requests.get(tempURL1).json()

tempURL2 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk={limit2}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

Q2_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q2_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']

# %%
Q2_tempDF1 = pd.DataFrame(Q2_tempL1)
Q2_tempDF2 = pd.DataFrame(Q2_tempL2)

# %%
def unListItemsQ2(col):
    lst_1 = [' ']*len(Q2_tempDF1[col])  # create empty list the length of 'Q1_tempDF1[col]'
    i = 0
    while i < len(Q2_tempDF1[col]):
        if len(Q2_tempDF1[col][i])==0:
            lst_1[i] = None
        else:
            lst_1[i] = Q2_tempDF1[col][i][0]
        i += 1
    lst_2 = [' ']*len(Q2_tempDF2[col])
    i = 0
    while i < len(Q2_tempDF2[col]):
        if len(Q2_tempDF2[col][i])==0:
            lst_2[i] = None
        else:
            lst_2[i] = Q2_tempDF2[col][i][0]
        i += 1      
    LIST = lst_1 + lst_2
    return LIST

# %%
#retrive unListed Items, populate Query1 DataFrame with query results from id, title, and date keys

ID = unListItemsQ2('NCTId')
Title = unListItemsQ2('BriefTitle')
VerifiedDate = unListItemsQ2('StatusVerifiedDate')
CompletionDate = unListItemsQ2('CompletionDate')
OrgFullName = unListItemsQ2('OrgFullName')
OrgClass = unListItemsQ2('OrgClass')
QueryType = ['coronavirus']*len(ID)
Country = unListItemsQ2('LocationCountry')
City = unListItemsQ2('LocationCity')
Participants = unListItemsQ2("EnrollmentCount")
Age_Groups = unListItemsQ2("StdAge")
Gender = unListItemsQ2("Gender")


DF_Q2 = pd.DataFrame()
DF_Q2.insert(0, 'ID', ID)
DF_Q2.insert(1, 'Title', Title)
DF_Q2.insert(2, 'Date Verified', VerifiedDate)
DF_Q2.insert(3, 'Completion Date', CompletionDate)
DF_Q2.insert(4, 'Organization', OrgFullName)
DF_Q2.insert(5, 'Organization Class', OrgClass)
DF_Q2.insert(6, 'Country', Country)
DF_Q2.insert(7, 'City', City)
DF_Q2.insert(8, 'Participants', Participants)
DF_Q2.insert(9, 'Age Groups', Age_Groups)
DF_Q2.insert(10, 'Gender', Gender)

# %%
DF_QQ = pd.concat([DF_Q1,DF_Q2], ignore_index=True)
DF_QQ = DF_QQ.drop_duplicates()
DF_QQ.set_index('ID', inplace=True)
DF_QQ
# Out:
#                                                          Title Date Verified  \
# ID
# NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...      May 2020
# NCT04395924         Maternal-foetal Transmission of SARS-Cov-2     June 2020
# NCT04476940  COVID-19 Breastfeeding Guideline for African-A...     July 2020
# NCT04412265          Frailty in Elderly Patients With COVID-19     June 2020
# NCT04427332     Smell and Taste Disorders in COVID-19 Patients     June 2020
# ...                                                        ...           ...
# NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...     June 2020
# NCT03823469  Evaluating the Impact of a Culinary Coaching T...      May 2020
# NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...     June 2020
# NCT03922334                        Navigating New Motherhood 2     June 2020
# NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...     June 2020
#
#                 Completion Date                           Organization  \
# ID
# NCT04395482    October 15, 2020           University of Milano Bicocca
# NCT04395924            May 2021  Centre Hospitalier Régional d'Orléans
# NCT04476940           June 2022                Meharry Medical College
# NCT04412265       March 1, 2021           University of Milano Bicocca
# NCT04427332  September 30, 2020           University of Milano Bicocca
# ...                         ...                                    ...
# NCT03728257       April 8, 2022               University of Pittsburgh
# NCT03823469       February 2022      Spaulding Rehabilitation Hospital
# NCT04429061       June 30, 2023    University of Alabama at Birmingham
# NCT03922334       December 2024                Northwestern University
# NCT04180709   November 30, 2022                University of Cambridge
#
#             Organization Class         Country         City Participants  \
# ID
# NCT04395482              OTHER           Italy      Bergamo          500
# NCT04395924              OTHER          France      Orléans           50
# NCT04476940              OTHER   United States    Nashville          200
# NCT04412265              OTHER           Italy        Monza          300
# NCT04427332              OTHER           Italy        Monza          500
# ...                        ...             ...          ...          ...
# NCT03728257              OTHER   United States   Pittsburgh          112
# NCT03823469              OTHER   United States  Charlestown           78
# NCT04429061              OTHER          Zambia       Lusaka         3200
# NCT03922334              OTHER   United States      Chicago          400
# NCT04180709              OTHER  United Kingdom    Cambridge           44
#
#             Age Groups  Gender
# ID
# NCT04395482      Adult     All
# NCT04395924      Adult  Female
# NCT04476940      Adult  Female
# NCT04412265      Adult     All
# NCT04427332      Adult     All
# ...                ...     ...
# NCT03728257      Adult     All
# NCT03823469      Adult     All
# NCT04429061      Child  Female
# NCT03922334      Child  Female
# NCT04180709      Adult     All
#
# [2779 rows x 10 columns]
