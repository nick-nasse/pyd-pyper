# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
#Create url search with Keywrod "COVID-19" containing the relevant fields we need for analysis and make single call to get data example
questURL = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest = requests.get(questURL).json()
Quest
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:30 00:15:40.081',
#   'Expression': 'covid 19',
#   'NStudiesAvail': 347327,
#   'NStudiesFound': 2949,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04395482'],
#     'BriefTitle': ['Lung CT Scan Analysis of SARS-CoV2 Induced Lung Injury'],
#     'StatusVerifiedDate': ['May 2020'],
#     'CompletionDate': ['October 15, 2020'],
#     'OrgFullName': ['University of Milano Bicocca'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['Lung injury', 'sars-covid-2', 'coronavirus infection'],
#     'LocationCity': ['Bergamo',
#      'Bergamo',
#      'Ferrara',
#      'Lecco',
#      'Melzo',
#      'Monza',
#      'Rimini',
#      'San Marino'],
#     'LocationCountry': ['Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'Italy',
#      'San Marino'],
#     'EnrollmentCount': ['500'],
#     'StdAge': ['Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
# Take the amount of possible results and use as our limit, so we know how many times to call the API
limit1 = Quest['StudyFieldsResponse']['NStudiesFound'] 
limit1
# Out:
# 2949

# %%
# Make our series of 3 requests and store them in three variables

tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   
tempL1 = requests.get(tempURL1).json()

tempURL2 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk=2000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

tempURL3 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=2001\
           &max_rnk={limit1}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL3 = requests.get(tempURL3).json()

Q1_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q1_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']
Q1_tempL3 = tempL3['StudyFieldsResponse']['StudyFields']

# %%
# Turn those variables into a Dataframe
Q1_tempDF1 = pd.DataFrame(Q1_tempL1)
Q1_tempDF2 = pd.DataFrame(Q1_tempL2)
Q1_tempDF3 = pd.DataFrame(Q1_tempL3)

# %%
# create function that cleans up the results and transforms column values into the necessary data types
def change_remove45(df):
    df = df.astype(str)
    df["NCTId"] = df["NCTId"].str.lstrip("['")
    df["NCTId"] = df["NCTId"].str.rstrip("']")
    df["BriefTitle"] = df["BriefTitle"].str.lstrip("['")
    df["BriefTitle"] = df["BriefTitle"].str.rstrip("']")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.lstrip("['")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.rstrip("']")
    df["CompletionDate"] = df["CompletionDate"].str.lstrip("['")
    df["CompletionDate"] = df["CompletionDate"].str.rstrip("']")
    df["OrgFullName"] = df["OrgFullName"].str.lstrip("['")
    df["OrgFullName"] = df["OrgFullName"].str.rstrip("']")
    df["OrgClass"] = df["OrgClass"].str.lstrip("['")
    df["OrgClass"] = df["OrgClass"].str.rstrip("']")
    df["Keyword"] = df["Keyword"].str.lstrip("['")
    df["Keyword"] = df["Keyword"].str.rstrip("']")
    df["LocationCity"] = df["LocationCity"].str.lstrip("['")
    df["LocationCity"] = df["LocationCity"].str.rstrip("']")
    df["LocationCountry"] = df["LocationCountry"].str.lstrip("['")
    df["LocationCountry"] = df["LocationCountry"].str.rstrip("']")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.lstrip("['")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.rstrip("']")
    df["StdAge"] = df["StdAge"].str.lstrip("['")
    df["StdAge"] = df["StdAge"].str.rstrip("']")
    df["Gender"] = df["Gender"].str.lstrip("['")
    df["Gender"] = df["Gender"].str.rstrip("']")
    df["LocationFacility"] = df["LocationFacility"].str.lstrip("['")
    df["LocationFacility"] = df["LocationFacility"].str.rstrip("']")
    df["StartDate"] = df["StartDate"].str.lstrip("['")
    df["StartDate"] = df["StartDate"].str.rstrip("']")
    df["LocationStatus"] = df["LocationStatus"].str.lstrip("['")
    df["LocationStatus"] = df["LocationStatus"].str.rstrip("']")
    df["NCTId"] = df["NCTId"].str.replace("'","")
    df["BriefTitle"] = df["BriefTitle"].str.replace("'","")
    df["StatusVerifiedDate"] = df["StatusVerifiedDate"].str.replace("'","")
    df["CompletionDate"] = df["CompletionDate"].str.replace("'","")
    df["OrgFullName"] = df["OrgFullName"].str.replace("'","")
    df["OrgClass"] = df["OrgClass"].str.replace("'","")
    df["Keyword"] = df["Keyword"].str.replace("'","")
    df["LocationCity"] = df["LocationCity"].str.replace("'","")
    df["LocationCountry"] = df["LocationCountry"].str.replace("'","")
    df["EnrollmentCount"] = df["EnrollmentCount"].str.replace("'","")
    df["StdAge"] = df["StdAge"].str.replace("'","")
    df["Gender"] = df["Gender"].str.replace("'","")
    df["StartDate"] = df["StartDate"].str.replace("'","")
    df["LocationFacility"] = df["LocationFacility"].str.replace("'","")
    df["LocationFacility"] = df["LocationStatus"].str.replace("'","")
    df["EnrollmentCount"] = pd.to_numeric(df["EnrollmentCount"])
    return df

# %%
# run the first dataframe against the function
clean_Q1_tempDF3 = change_remove45(Q1_tempDF3)
clean_Q1_tempDF3
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    2001  NCT04375501  A Study of Outcomes in Patients With Fractured...
# 1    2002  NCT04378920  A Study of Trans Crocetin in Patients With Acu...
# 2    2003  NCT04416009          Extracellular Water in Covid 19 Pneumonia
# 3    2004  NCT04389671  The Safety and Preliminary Efficacy of Lucinac...
# 4    2005  NCT04320472  Acute Encephalopathy in Critically Ill Patient...
# ..    ...          ...                                                ...
# 944  2945  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 945  2946  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 946  2947  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 947  2948  NCT03922334                        Navigating New Motherhood 2
# 948  2949  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#     StatusVerifiedDate         StartDate     CompletionDate  \
# 0             May 2020  February 1, 2020     April 15, 2020
# 1             May 2020    April 14, 2020   October 31, 2020
# 2            June 2020      July 5, 2020  February 20, 2021
# 3             May 2020      June 1, 2020      November 2020
# 4            June 2020    March 23, 2020      December 2020
# ..                 ...               ...                ...
# 944          June 2020    March 25, 2019      April 8, 2022
# 945           May 2020      May 20, 2019      February 2022
# 946          June 2020     March 1, 2020      June 30, 2023
# 947          June 2020  January 21, 2020      December 2024
# 948          June 2020   August 31, 2020  November 30, 2022
#
#                                            OrgFullName   OrgClass  \
# 0                         Barts & The London NHS Trust      OTHER
# 1           Institut de Cancerologie Strasbourg Europe      OTHER
# 2    Gaziosmanpasa Taksim Research and Education Ho...  OTHER_GOV
# 3                                Windtree Therapeutics   INDUSTRY
# 4                                          Ictal Group      OTHER
# ..                                                 ...        ...
# 944                           University of Pittsburgh      OTHER
# 945                  Spaulding Rehabilitation Hospital      OTHER
# 946                University of Alabama at Birmingham      OTHER
# 947                            Northwestern University      OTHER
# 948                            University of Cambridge      OTHER
#
#                                                Keyword  \
# 0    COVID-19, Coronavirus, Neck of femur, Morbidit...
# 1
# 2                           covid-19, NİCaS, pneumonia
# 3
# 4
# ..                                                 ...
# 944
# 945  Home cooking, Telemedicine, Nutrition, Health ...
# 946                      Adolescents, Zambia, Football
# 947
# 948  Cognition, Social Recovery, Immunopsychiatry, ...
#
#                                       LocationFacility  \
# 0
# 1                               Recruiting, Recruiting
# 2                                           Recruiting
# 3
# 4    Recruiting, Recruiting, Recruiting, Recruiting...
# ..                                                 ...
# 944                                         Recruiting
# 945                              Completed, Recruiting
# 946                                         Recruiting
# 947                                         Recruiting
# 948
#
#                                         LocationStatus  \
# 0
# 1                             Recruiting', 'Recruiting
# 2                                           Recruiting
# 3
# 4    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# ..                                                 ...
# 944                                         Recruiting
# 945                            Completed', 'Recruiting
# 946                                         Recruiting
# 947                                         Recruiting
# 948
#
#                                           LocationCity  \
# 0                                               London
# 1                               Strasbourg, Strasbourg
# 2                                             Istanbul
# 3
# 4    Miami, Atlanta, São Paulo, Cali, Argenteuil, B...
# ..                                                 ...
# 944                                         Pittsburgh
# 945                             Charlestown, Ramat Gan
# 946                                             Lusaka
# 947                                            Chicago
# 948                                          Cambridge
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                       United Kingdom            442.0
# 1                                       France, France            180.0
# 2                                               Turkey             52.0
# 3                                                                  30.0
# 4    United States, United States, Brazil, Colombia...            250.0
# ..                                                 ...              ...
# 944                                      United States            112.0
# 945                              United States, Israel             78.0
# 946                                             Zambia           3200.0
# 947                                      United States            400.0
# 948                                     United Kingdom             44.0
#
#                         StdAge  Gender
# 0           Adult, Older Adult     All
# 1           Adult, Older Adult     All
# 2           Adult, Older Adult     All
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 944         Adult, Older Adult     All
# 945         Adult, Older Adult     All
# 946  Child, Adult, Older Adult  Female
# 947               Child, Adult  Female
# 948         Adult, Older Adult     All
#
# [949 rows x 16 columns]

# %%
# run the second dataframe against the function
clean_Q1_tempDF2 = change_remove45(Q1_tempDF2)
clean_Q1_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04387214  COVID-19 Pandemic and Academic Performance of ...
# 1    1002  NCT04472013  Systematic Assessment of SARS-CoV-2 Neurotropi...
# 2    1003  NCT04354870                        COVID-19 PrEP HCW HCQ Study
# 3    1004  NCT04460534  Detection of COVID-19 (SARS-CoV-2) in the Seme...
# 4    1005  NCT04306497  TCM Differentiation and Treatment Protocol of ...
# ..    ...          ...                                                ...
# 995  1996  NCT04336215                      Rutgers COVID-19 Cohort Study
# 996  1997  NCT04389671  The Safety and Preliminary Efficacy of Lucinac...
# 997  1998  NCT04468646  To Determine the Efficacy of Neurokinin 1 Rece...
# 998  1999  NCT04336748  HCQ for Primary Prophylaxis Against COVID19 in...
# 999  2000  NCT04451174  Early Use of Corticosteroids in Hospitalized P...
#
#     StatusVerifiedDate         StartDate      CompletionDate  \
# 0            June 2020    April 13, 2020        May 31, 2020
# 1            July 2020    September 2020       December 2022
# 2           April 2020     April 3, 2020   September 1, 2020
# 3            July 2020       May 7, 2020     August 31, 2021
# 4            June 2020  January 22, 2020        May 30, 2020
# ..                 ...               ...                 ...
# 995         April 2020     April 7, 2020    October 21, 2021
# 996           May 2020      June 1, 2020       November 2020
# 997          July 2020     June 15, 2020     August 30, 2020
# 998         April 2020        April 2020         August 2020
# 999          July 2020     June 23, 2020  September 30, 2020
#
#                                            OrgFullName  OrgClass  \
# 0                              South Valley University     OTHER
# 1              University Hospital, Basel, Switzerland     OTHER
# 2                                   NYU Langone Health     OTHER
# 3    GCS Ramsay Santé pour l’Enseignement et la Rec...     OTHER
# 4          Jiangsu Famous Medical Technology Co., Ltd.  INDUSTRY
# ..                                                 ...       ...
# 995        Rutgers, The State University of New Jersey     OTHER
# 996                              Windtree Therapeutics  INDUSTRY
# 997               University of Health Sciences Lahore     OTHER
# 998                       Medical University of Vienna     OTHER
# 999                                University of Chile     OTHER
#
#                                                Keyword  \
# 0
# 1    SARS-CoV-2, neurotropism of SARS-CoV-2, microg...
# 2
# 3
# 4    COVID-19, Syndrome investigation, differentiat...
# ..                                                 ...
# 995
# 996
# 997  neurokinin 1 receptor, Substance P, Respirator...
# 998
# 999
#
#                                       LocationFacility  \
# 0
# 1                               Recruiting, Recruiting
# 2                                           Recruiting
# 3                                           Recruiting
# 4
# ..                                                 ...
# 995  Recruiting, Recruiting, Recruiting, Recruiting...
# 996
# 997                                         Recruiting
# 998
# 999                                         Recruiting
#
#                                         LocationStatus  \
# 0
# 1                             Recruiting', 'Recruiting
# 2                                           Recruiting
# 3                                           Recruiting
# 4
# ..                                                 ...
# 995  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 996
# 997                                         Recruiting
# 998
# 999                                         Recruiting
#
#                                           LocationCity  \
# 0                                                 Qinā
# 1                                       Basel, Liestal
# 2                                             New York
# 3                                           Le Chesnay
# 4                                               Huaian
# ..                                                 ...
# 995  New Brunswick, New Brunswick, Newark, Newark, ...
# 996
# 997                                             Lahore
# 998
# 999                                           Santiago
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                                Egypt            857.0
# 1                             Switzerland, Switzerland             40.0
# 2                                        United States            350.0
# 3                                               France            100.0
# 4                                                China            340.0
# ..                                                 ...              ...
# 995  United States, United States, United States, U...            750.0
# 996                                                                30.0
# 997                                           Pakistan            100.0
# 998                                                               440.0
# 999                                              Chile            184.0
#
#                  StdAge Gender
# 0          Child, Adult    All
# 1    Adult, Older Adult    All
# 2    Adult, Older Adult    All
# 3    Adult, Older Adult   Male
# 4    Adult, Older Adult    All
# ..                  ...    ...
# 995  Adult, Older Adult    All
# 996  Adult, Older Adult    All
# 997  Adult, Older Adult    All
# 998  Adult, Older Adult    All
# 999  Adult, Older Adult    All
#
# [1000 rows x 16 columns]

# %%
# run the 3rd dataframe against the function
clean_Q1_tempDF1 = change_remove45(Q1_tempDF1)
clean_Q1_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1       2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4       5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ..    ...          ...                                                ...
# 995   996  NCT04410328                   Aggrenox To Treat Acute Covid-19
# 996   997  NCT04342221                    Hydroxychloroquine for COVID-19
# 997   998  NCT04420247  Efficacy of Chloroquine or Hydroxychloroquine ...
# 998   999  NCT04342182  Convalescent Plasma as Therapy for Covid-19 Se...
# 999  1000  NCT04397237  Prevalence and Seroconversion of COVID-19 in A...
#
#     StatusVerifiedDate       StartDate      CompletionDate  \
# 0            June 2020     May 5, 2020            May 2021
# 1             May 2020  April 15, 2020    October 15, 2020
# 2            July 2020  September 2020           June 2022
# 3            June 2020   March 1, 2020       March 1, 2021
# 4            June 2020    May 15, 2020  September 30, 2020
# ..                 ...             ...                 ...
# 995          July 2020   July 28, 2020   December 15, 2021
# 996         March 2020  March 29, 2020       February 2022
# 997          June 2020  April 16, 2020     August 31, 2020
# 998           May 2020   April 8, 2020        July 1, 2020
# 999           May 2020        May 2020       December 2020
#
#                                            OrgFullName OrgClass  \
# 0               "Centre Hospitalier Régional dOrléans"    OTHER
# 1                         University of Milano Bicocca    OTHER
# 2                              Meharry Medical College    OTHER
# 3                         University of Milano Bicocca    OTHER
# 4                         University of Milano Bicocca    OTHER
# ..                                                 ...      ...
# 995        Rutgers, The State University of New Jersey    OTHER
# 996                      University Hospital Tuebingen    OTHER
# 997  Centro de Estudos e Pesquisa em Emergencias Me...    OTHER
# 998                             Erasmus Medical Center    OTHER
# 999                         Pitié-Salpêtrière Hospital    OTHER
#
#                                                Keyword  \
# 0    Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1     Lung injury, sars-covid-2, coronavirus infection
# 2    COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3    Coronavirus, sars-covid-2, coronavirus infecti...
# 4     Coronavirus, sars-covid-2, coronavirus infection
# ..                                                 ...
# 995  COVID-19, SARS-CoV, Aggrenox, Dipyridamole, As...
# 996
# 997  VIRAL PNEUMONIA, CORONAVIRUS, COVID-19, COVID,...
# 998
# 999  COVID-19, Systemic Lupus Erythematosus, "Sjogr...
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1    Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995
# 996  Recruiting, Recruiting, Recruiting, Recruiting...
# 997                                         Recruiting
# 998  Recruiting, Recruiting, Recruiting, Recruiting...
# 999
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995
# 996  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 997                                         Recruiting
# 998  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 999
#
#                                           LocationCity  \
# 0                                              Orléans
# 1    Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                            Nashville
# 3                                                Monza
# 4                                                Monza
# ..                                                 ...
# 995
# 996  Balingen, Darmstadt, Hamburg, Minden, Reutling...
# 997                                           Curitiba
# 998  Rotterdam, Alkmaar, Amsterdam, Arnhem, Delft, ...
# 999
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                               France             50.0
# 1    Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                        United States            200.0
# 3                                                Italy            300.0
# 4                                                Italy            500.0
# ..                                                 ...              ...
# 995                                                               132.0
# 996  Germany, Germany, Germany, Germany, Germany, G...            220.0
# 997                                             Brazil            100.0
# 998  Netherlands, Netherlands, Netherlands, Netherl...            426.0
# 999                                                              3600.0
#
#                  StdAge  Gender
# 0                 Adult  Female
# 1    Adult, Older Adult     All
# 2                 Adult  Female
# 3    Adult, Older Adult     All
# 4    Adult, Older Adult     All
# ..                  ...     ...
# 995  Adult, Older Adult     All
# 996  Adult, Older Adult     All
# 997  Adult, Older Adult     All
# 998  Adult, Older Adult     All
# 999  Adult, Older Adult     All
#
# [1000 rows x 16 columns]

# %%
#Create url search with Keywrod "COVID-19" containing the relevant fields we need for analysis and make single call to get data example
query = 'coronavirus'
quest2URL = f'http://ClinicalTrials.gov/api/query/study_fields?expr={query}\
           &min_rnk=1\
           &max_rnk=1\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
Quest2 = requests.get(quest2URL).json()
Quest2
# Out:
# {'StudyFieldsResponse': {'APIVrs': '1.01.02',
#   'DataVrs': '2020:07:30 00:15:40.081',
#   'Expression': 'coronavirus',
#   'NStudiesAvail': 347327,
#   'NStudiesFound': 1491,
#   'MinRank': 1,
#   'MaxRank': 1,
#   'NStudiesReturned': 1,
#   'FieldList': ['NCTId',
#    'BriefTitle',
#    'StatusVerifiedDate',
#    'StartDate',
#    'CompletionDate',
#    'OrgFullName',
#    'OrgClass',
#    'Keyword',
#    'LocationFacility',
#    'LocationStatus',
#    'LocationCity',
#    'LocationCountry',
#    'EnrollmentCount',
#    'StdAge',
#    'Gender'],
#   'StudyFields': [{'Rank': 1,
#     'NCTId': ['NCT04279795'],
#     'BriefTitle': ['Detection of 2019 Novel Coronavirus in Multiple Organ System and Its Relationship With Clinical Manifestations'],
#     'StatusVerifiedDate': ['February 2020'],
#     'StartDate': ['January 20, 2020'],
#     'CompletionDate': ['February 28, 2021'],
#     'OrgFullName': ['Third Affiliated Hospital, Sun Yat-Sen University'],
#     'OrgClass': ['OTHER'],
#     'Keyword': ['2019 Novel Coronavirus'],
#     'LocationFacility': ['The Third Affiliated Hospital of Sun Yat-sen University'],
#     'LocationStatus': ['Recruiting'],
#     'LocationCity': ['Guangzhou'],
#     'LocationCountry': ['China'],
#     'EnrollmentCount': ['20'],
#     'StdAge': ['Child', 'Adult', 'Older Adult'],
#     'Gender': ['All']}]}}

# %%
# Take the amount of possible results and use as our limit, so we know how many times to call the API
limit2 = Quest2['StudyFieldsResponse']['NStudiesFound'] 
limit2
# Out:
# 1491

# %%
# Make our series of 2 requests and store them in three variables
tempURL1 = 'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1\
           &max_rnk=1000\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'   

tempL1 = requests.get(tempURL1).json()

tempURL2 = f'http://ClinicalTrials.gov/api/query/study_fields?expr=covid+19\
           &min_rnk=1001\
           &max_rnk={limit2}\
           &fields=\
               NCTId,\
               BriefTitle,\
               StatusVerifiedDate,\
               StartDate,\
               CompletionDate,\
               OrgFullName,\
               OrgClass,\
               keyword,\
               LocationFacility,\
               LocationStatus,\
               LocationCity,\
               LocationCountry,\
               EnrollmentCount,\
               STDAge,\
               Gender\
           &fmt=JSON'
tempL2 = requests.get(tempURL2).json()                                                             

Q2_tempL1 = tempL1['StudyFieldsResponse']['StudyFields']
Q2_tempL2 = tempL2['StudyFieldsResponse']['StudyFields']

# %%
# Turn the variables into DataFrames
Q2_tempDF1 = pd.DataFrame(Q2_tempL1)
Q2_tempDF2 = pd.DataFrame(Q2_tempL2)

# %%
# run the 4th dataframe against the function
clean_Q2_tempDF1 = change_remove45(Q2_tempDF1)
clean_Q2_tempDF1
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 1       2  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4       5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ..    ...          ...                                                ...
# 995   996  NCT04341480  The Safety of Chemotherapy for Patients With G...
# 996   997  NCT04445389  Safety and Immunogenicity Study of GX-19, a CO...
# 997   998  NCT04383886  Evaluation of Emergency Department (ED) Staff ...
# 998   999  NCT04393311  Ulinastatin for the Treatment of COVID-19 in H...
# 999  1000  NCT04351919  Assessment of Efficacy and Safety of HCQ and A...
#
#     StatusVerifiedDate       StartDate      CompletionDate  \
# 0             May 2020  April 15, 2020    October 15, 2020
# 1            June 2020     May 5, 2020            May 2021
# 2            July 2020  September 2020           June 2022
# 3            June 2020   March 1, 2020       March 1, 2021
# 4            June 2020    May 15, 2020  September 30, 2020
# ..                 ...             ...                 ...
# 995         April 2020  April 10, 2020       July 10, 2020
# 996          July 2020   June 17, 2020       June 17, 2022
# 997         April 2020  April 18, 2020     August 18, 2020
# 998           May 2020       July 2020        January 2021
# 999           May 2020     May 5, 2020       July 15, 2020
#
#                                 OrgFullName  OrgClass  \
# 0              University of Milano Bicocca     OTHER
# 1    "Centre Hospitalier Régional dOrléans"     OTHER
# 2                   Meharry Medical College     OTHER
# 3              University of Milano Bicocca     OTHER
# 4              University of Milano Bicocca     OTHER
# ..                                      ...       ...
# 995                         Tongji Hospital     OTHER
# 996                          Genexine, Inc.  INDUSTRY
# 997                 Hospices Civils de Lyon     OTHER
# 998                     Stanford University     OTHER
# 999              Abderrahmane Mami Hospital     OTHER
#
#                                                Keyword  \
# 0     Lung injury, sars-covid-2, coronavirus infection
# 1    Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 2    COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3    Coronavirus, sars-covid-2, coronavirus infecti...
# 4     Coronavirus, sars-covid-2, coronavirus infection
# ..                                                 ...
# 995  COVID-19, SARS-CoV-2, Gynecological cancer, Ch...
# 996
# 997  COVID-19 pandemic, level of stress, emergency ...
# 998
# 999
#
#                                       LocationFacility  \
# 0    Recruiting, Recruiting, Recruiting, Recruiting...
# 1                                           Recruiting
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995
# 996                                         Recruiting
# 997  Recruiting, Recruiting, Recruiting, Recruiting...
# 998
# 999
#
#                                         LocationStatus  \
# 0    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 1                                           Recruiting
# 2
# 3                                           Recruiting
# 4                                           Recruiting
# ..                                                 ...
# 995
# 996                                         Recruiting
# 997  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 998
# 999
#
#                                           LocationCity  \
# 0    Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 1                                              Orléans
# 2                                            Nashville
# 3                                                Monza
# 4                                                Monza
# ..                                                 ...
# 995                                              Wuhan
# 996                                              Seoul
# 997  Lyon, Lyon, Lyon, Pierre-Bénite, Villefranche-...
# 998                                           Stanford
# 999                                              Tunis
#
#                                        LocationCountry  EnrollmentCount  \
# 0    Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 1                                               France             50.0
# 2                                        United States            200.0
# 3                                                Italy            300.0
# 4                                                Italy            500.0
# ..                                                 ...              ...
# 995                                              China            207.0
# 996                                 Korea, Republic of            210.0
# 997             France, France, France, France, France            200.0
# 998                                      United States            150.0
# 999                                            Tunisia            400.0
#
#                  StdAge  Gender
# 0    Adult, Older Adult     All
# 1                 Adult  Female
# 2                 Adult  Female
# 3    Adult, Older Adult     All
# 4    Adult, Older Adult     All
# ..                  ...     ...
# 995  Adult, Older Adult  Female
# 996               Adult     All
# 997  Adult, Older Adult     All
# 998  Adult, Older Adult     All
# 999  Adult, Older Adult     All
#
# [1000 rows x 16 columns]

# %%
# run the 5th dataframe against the function
clean_Q2_tempDF2 = change_remove45(Q2_tempDF2)
clean_Q2_tempDF2
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0    1001  NCT04432805  Descriptive and Evaluation Study of the Use of...
# 1    1002  NCT04320277  Baricitinib in Symptomatic Patients Infected b...
# 2    1003  NCT04445389  Safety and Immunogenicity Study of GX-19, a CO...
# 3    1004  NCT04352842  Echocardiographic Manifestation in Patient Wit...
# 4    1005  NCT04346342  PRactice of VENTilation in COVID-19 Patients (...
# ..    ...          ...                                                ...
# 486  1487  NCT04347941  Awake Prone Positioning to Reduce Invasive VEn...
# 487  1488  NCT04390464  mulTi-Arm Therapeutic Study in Pre-ICu Patient...
# 488  1489  NCT04335552  Pragmatic Factorial Trial of Hydroxychloroquin...
# 489  1490  NCT04359277  A Randomized Trial of Anticoagulation Strategi...
# 490  1491  NCT04341688  A Clinical Trial of Gargling Agents in Reducin...
#
#     StatusVerifiedDate         StartDate   CompletionDate  \
# 0            June 2020     June 15, 2020    June 15, 2021
# 1           April 2020      May 16, 2020    July 30, 2020
# 2            July 2020     June 17, 2020    June 17, 2022
# 3           April 2020  January 21, 2020    April 8, 2020
# 4            July 2020     March 6, 2020  October 1, 2020
# ..                 ...               ...              ...
# 486         April 2020    April 11, 2020     May 11, 2021
# 487           May 2020       May 8, 2020      May 1, 2022
# 488         April 2020    April 17, 2020   August 1, 2020
# 489          June 2020    April 21, 2020   April 21, 2021
# 490          June 2020    August 1, 2020   March 31, 2021
#
#                                            OrgFullName  OrgClass  \
# 0            Assistance Publique Hopitaux De Marseille     OTHER
# 1                                    Hospital of Prato     OTHER
# 2                                       Genexine, Inc.  INDUSTRY
# 3                                       RenJi Hospital     OTHER
# 4    Academisch Medisch Centrum - Universiteit van ...     OTHER
# ..                                                 ...       ...
# 486                 University College Hospital Galway     OTHER
# 487  Cambridge University Hospitals NHS Foundation ...     OTHER
# 488                                    Duke University     OTHER
# 489                                 NYU Langone Health     OTHER
# 490                                Aga Khan University     OTHER
#
#                                                Keyword  \
# 0
# 1    COVID-19, Baricitinib, Moderate disease, Infec...
# 2
# 3    COVID-19, Echocardiography, cardiac structure,...
# 4                                                COVID
# ..                                                 ...
# 486
# 487
# 488                                           COVID-19
# 489
# 490  Covid-19;, coronavirus disease, povidone, hydr...
#
#                                       LocationFacility  \
# 0                                           Recruiting
# 1
# 2                                           Recruiting
# 3
# 4    Recruiting, Recruiting, Recruiting, Recruiting...
# ..                                                 ...
# 486
# 487                                         Recruiting
# 488  Recruiting, Recruiting, Not yet recruiting, Re...
# 489                                         Recruiting
# 490
#
#                                         LocationStatus  \
# 0                                           Recruiting
# 1
# 2                                           Recruiting
# 3
# 4    Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# ..                                                 ...
# 486
# 487                                         Recruiting
# 488  Recruiting', 'Recruiting', 'Not yet recruiting...
# 489                                         Recruiting
# 490
#
#                                           LocationCity  \
# 0                                            Marseille
# 1                                                Prato
# 2                                                Seoul
# 3                                             Shanghai
# 4    Almere, Amsterdam, Amsterdam, Apeldoorn, Arnhe...
# ..                                                 ...
# 486                                             Galway
# 487                                          Cambridge
# 488                    Durham, Durham, Durham, Raleigh
# 489                                           New York
# 490
#
#                                        LocationCountry  EnrollmentCount  \
# 0                                               France            160.0
# 1                                                Italy            200.0
# 2                                   Korea, Republic of            210.0
# 3                                                China             51.0
# 4    Netherlands, Netherlands, Netherlands, Netherl...           1000.0
# ..                                                 ...              ...
# 486                                            Ireland            200.0
# 487                                     United Kingdom           1167.0
# 488  United States, United States, United States, U...            500.0
# 489                                      United States           1000.0
# 490                                                                50.0
#
#                         StdAge  Gender
# 0           Adult, Older Adult  Female
# 1           Adult, Older Adult     All
# 2                        Adult     All
# 3           Adult, Older Adult     All
# 4           Adult, Older Adult     All
# ..                         ...     ...
# 486         Adult, Older Adult     All
# 487         Adult, Older Adult     All
# 488  Child, Adult, Older Adult     All
# 489         Adult, Older Adult     All
# 490         Adult, Older Adult     All
#
# [491 rows x 16 columns]

# %%
# combine all 5 dataframes into a single, large dataframe
DF_QQ = pd.concat([clean_Q1_tempDF1, clean_Q1_tempDF2, clean_Q1_tempDF3, clean_Q2_tempDF1, clean_Q2_tempDF2], ignore_index=True)
DF_QQ = DF_QQ.drop_duplicates()
DF_QQ
# Out:
#       Rank        NCTId                                         BriefTitle  \
# 0        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2        3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3        4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4        5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ...    ...          ...                                                ...
# 4435  1487  NCT04347941  Awake Prone Positioning to Reduce Invasive VEn...
# 4436  1488  NCT04390464  mulTi-Arm Therapeutic Study in Pre-ICu Patient...
# 4437  1489  NCT04335552  Pragmatic Factorial Trial of Hydroxychloroquin...
# 4438  1490  NCT04359277  A Randomized Trial of Anticoagulation Strategi...
# 4439  1491  NCT04341688  A Clinical Trial of Gargling Agents in Reducin...
#
#      StatusVerifiedDate       StartDate      CompletionDate  \
# 0             June 2020     May 5, 2020            May 2021
# 1              May 2020  April 15, 2020    October 15, 2020
# 2             July 2020  September 2020           June 2022
# 3             June 2020   March 1, 2020       March 1, 2021
# 4             June 2020    May 15, 2020  September 30, 2020
# ...                 ...             ...                 ...
# 4435         April 2020  April 11, 2020        May 11, 2021
# 4436           May 2020     May 8, 2020         May 1, 2022
# 4437         April 2020  April 17, 2020      August 1, 2020
# 4438          June 2020  April 21, 2020      April 21, 2021
# 4439          June 2020  August 1, 2020      March 31, 2021
#
#                                             OrgFullName OrgClass  \
# 0                "Centre Hospitalier Régional dOrléans"    OTHER
# 1                          University of Milano Bicocca    OTHER
# 2                               Meharry Medical College    OTHER
# 3                          University of Milano Bicocca    OTHER
# 4                          University of Milano Bicocca    OTHER
# ...                                                 ...      ...
# 4435                 University College Hospital Galway    OTHER
# 4436  Cambridge University Hospitals NHS Foundation ...    OTHER
# 4437                                    Duke University    OTHER
# 4438                                 NYU Langone Health    OTHER
# 4439                                Aga Khan University    OTHER
#
#                                                 Keyword  \
# 0     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1      Lung injury, sars-covid-2, coronavirus infection
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Coronavirus, sars-covid-2, coronavirus infecti...
# 4      Coronavirus, sars-covid-2, coronavirus infection
# ...                                                 ...
# 4435
# 4436
# 4437                                           COVID-19
# 4438
# 4439  Covid-19;, coronavirus disease, povidone, hydr...
#
#                                        LocationFacility  \
# 0                                            Recruiting
# 1     Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 4435
# 4436                                         Recruiting
# 4437  Recruiting, Recruiting, Not yet recruiting, Re...
# 4438                                         Recruiting
# 4439
#
#                                          LocationStatus  \
# 0                                            Recruiting
# 1     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 4435
# 4436                                         Recruiting
# 4437  Recruiting', 'Recruiting', 'Not yet recruiting...
# 4438                                         Recruiting
# 4439
#
#                                            LocationCity  \
# 0                                               Orléans
# 1     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                             Nashville
# 3                                                 Monza
# 4                                                 Monza
# ...                                                 ...
# 4435                                             Galway
# 4436                                          Cambridge
# 4437                    Durham, Durham, Durham, Raleigh
# 4438                                           New York
# 4439
#
#                                         LocationCountry  EnrollmentCount  \
# 0                                                France             50.0
# 1     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                         United States            200.0
# 3                                                 Italy            300.0
# 4                                                 Italy            500.0
# ...                                                 ...              ...
# 4435                                            Ireland            200.0
# 4436                                     United Kingdom           1167.0
# 4437  United States, United States, United States, U...            500.0
# 4438                                      United States           1000.0
# 4439                                                                50.0
#
#                          StdAge  Gender
# 0                         Adult  Female
# 1            Adult, Older Adult     All
# 2                         Adult  Female
# 3            Adult, Older Adult     All
# 4            Adult, Older Adult     All
# ...                         ...     ...
# 4435         Adult, Older Adult     All
# 4436         Adult, Older Adult     All
# 4437  Child, Adult, Older Adult     All
# 4438         Adult, Older Adult     All
# 4439         Adult, Older Adult     All
#
# [4389 rows x 16 columns]

# %%
# check for dupes
dupe_dupe = DF_QQ.pivot_table(index=['NCTId'], aggfunc='size')
print (dupe_dupe)
# Out:
# NCTId
# NCT01306084    1
# NCT02517489    1
# NCT02656381    1
# NCT02735707    1
# NCT02765191    1
#               ..
# NCT04493242    2
# NCT04493268    2
# NCT04493294    2
# NCT04493307    2
# NCT04493359    2
# Length: 2919, dtype: int64

# %%
# drop duplicates
df_final = DF_QQ.drop_duplicates(subset='NCTId', keep="first")
df_final
# Out:
#      Rank        NCTId                                         BriefTitle  \
# 0       1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1       2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2       3  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 3       4  NCT04412265          Frailty in Elderly Patients With COVID-19
# 4       5  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# ...   ...          ...                                                ...
# 3929  981  NCT04321421  Hyperimmune Plasma for Critical Patients With ...
# 3933  985  NCT04489446                             Sildenafil in COVID-19
# 3936  988  NCT04438993      The COVID-19 Disease and CARdiac Events Study
# 3945  997  NCT04445389  Safety and Immunogenicity Study of GX-19, a CO...
# 3947  999  NCT04393311  Ulinastatin for the Treatment of COVID-19 in H...
#
#      StatusVerifiedDate       StartDate      CompletionDate  \
# 0             June 2020     May 5, 2020            May 2021
# 1              May 2020  April 15, 2020    October 15, 2020
# 2             July 2020  September 2020           June 2022
# 3             June 2020   March 1, 2020       March 1, 2021
# 4             June 2020    May 15, 2020  September 30, 2020
# ...                 ...             ...                 ...
# 3929           May 2020  March 17, 2020         May 7, 2020
# 3933          July 2020     August 2020          March 2021
# 3936          June 2020    May 29, 2020       November 2020
# 3945          July 2020   June 17, 2020       June 17, 2022
# 3947           May 2020       July 2020        January 2021
#
#                                  OrgFullName   OrgClass  \
# 0     "Centre Hospitalier Régional dOrléans"      OTHER
# 1               University of Milano Bicocca      OTHER
# 2                    Meharry Medical College      OTHER
# 3               University of Milano Bicocca      OTHER
# 4               University of Milano Bicocca      OTHER
# ...                                      ...        ...
# 3929    Foundation IRCCS San Matteo Hospital      OTHER
# 3933       Universidad Nacional Andres Bello      OTHER
# 3936                         NHS Lanarkshire  OTHER_GOV
# 3945                          Genexine, Inc.   INDUSTRY
# 3947                     Stanford University      OTHER
#
#                                                 Keyword  \
# 0     Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# 1      Lung injury, sars-covid-2, coronavirus infection
# 2     COVID-19, Exclusive Breastfeeding, Breastfeedi...
# 3     Coronavirus, sars-covid-2, coronavirus infecti...
# 4      Coronavirus, sars-covid-2, coronavirus infection
# ...                                                 ...
# 3929                       hyperimmune plasma, COVID-19
# 3933  COVID19, SARS-COV2 Infection, Sildenafil, Phos...
# 3936     Echocardiogram, Troponin, NT-proBNP, Cytokines
# 3945
# 3947
#
#                                        LocationFacility  \
# 0                                            Recruiting
# 1     Recruiting, Recruiting, Recruiting, Recruiting...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3929
# 3933
# 3936                                         Recruiting
# 3945                                         Recruiting
# 3947
#
#                                          LocationStatus  \
# 0                                            Recruiting
# 1     Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# 2
# 3                                            Recruiting
# 4                                            Recruiting
# ...                                                 ...
# 3929
# 3933
# 3936                                         Recruiting
# 3945                                         Recruiting
# 3947
#
#                                            LocationCity  \
# 0                                               Orléans
# 1     Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# 2                                             Nashville
# 3                                                 Monza
# 4                                                 Monza
# ...                                                 ...
# 3929                                     Pavia, Mantova
# 3933                                       Viña Del Mar
# 3936                                            Glasgow
# 3945                                              Seoul
# 3947                                           Stanford
#
#                                         LocationCountry  EnrollmentCount  \
# 0                                                France             50.0
# 1     Italy, Italy, Italy, Italy, Italy, Italy, Ital...            500.0
# 2                                         United States            200.0
# 3                                                 Italy            300.0
# 4                                                 Italy            500.0
# ...                                                 ...              ...
# 3929                                       Italy, Italy             49.0
# 3933                                              Chile             40.0
# 3936                                     United Kingdom            100.0
# 3945                                 Korea, Republic of            210.0
# 3947                                      United States            150.0
#
#                   StdAge  Gender
# 0                  Adult  Female
# 1     Adult, Older Adult     All
# 2                  Adult  Female
# 3     Adult, Older Adult     All
# 4     Adult, Older Adult     All
# ...                  ...     ...
# 3929  Adult, Older Adult     All
# 3933  Adult, Older Adult     All
# 3936  Adult, Older Adult     All
# 3945               Adult     All
# 3947  Adult, Older Adult     All
#
# [2919 rows x 16 columns]

# %%
# set the index to Study ID
df_final.set_index('NCTId', inplace=True)
df_final
# Out:
#             Rank                                         BriefTitle  \
# NCTId
# NCT04395924    1         Maternal-foetal Transmission of SARS-Cov-2
# NCT04395482    2  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# NCT04476940    3  COVID-19 Breastfeeding Guideline for African-A...
# NCT04412265    4          Frailty in Elderly Patients With COVID-19
# NCT04427332    5     Smell and Taste Disorders in COVID-19 Patients
# ...          ...                                                ...
# NCT04321421  981  Hyperimmune Plasma for Critical Patients With ...
# NCT04489446  985                             Sildenafil in COVID-19
# NCT04438993  988      The COVID-19 Disease and CARdiac Events Study
# NCT04445389  997  Safety and Immunogenicity Study of GX-19, a CO...
# NCT04393311  999  Ulinastatin for the Treatment of COVID-19 in H...
#
#             StatusVerifiedDate       StartDate      CompletionDate  \
# NCTId
# NCT04395924          June 2020     May 5, 2020            May 2021
# NCT04395482           May 2020  April 15, 2020    October 15, 2020
# NCT04476940          July 2020  September 2020           June 2022
# NCT04412265          June 2020   March 1, 2020       March 1, 2021
# NCT04427332          June 2020    May 15, 2020  September 30, 2020
# ...                        ...             ...                 ...
# NCT04321421           May 2020  March 17, 2020         May 7, 2020
# NCT04489446          July 2020     August 2020          March 2021
# NCT04438993          June 2020    May 29, 2020       November 2020
# NCT04445389          July 2020   June 17, 2020       June 17, 2022
# NCT04393311           May 2020       July 2020        January 2021
#
#                                         OrgFullName   OrgClass  \
# NCTId
# NCT04395924  "Centre Hospitalier Régional dOrléans"      OTHER
# NCT04395482            University of Milano Bicocca      OTHER
# NCT04476940                 Meharry Medical College      OTHER
# NCT04412265            University of Milano Bicocca      OTHER
# NCT04427332            University of Milano Bicocca      OTHER
# ...                                             ...        ...
# NCT04321421    Foundation IRCCS San Matteo Hospital      OTHER
# NCT04489446       Universidad Nacional Andres Bello      OTHER
# NCT04438993                         NHS Lanarkshire  OTHER_GOV
# NCT04445389                          Genexine, Inc.   INDUSTRY
# NCT04393311                     Stanford University      OTHER
#
#                                                        Keyword  \
# NCTId
# NCT04395924  Pregnancy, RT-PCR-COVID-19, SARS-CoV 2 serolog...
# NCT04395482   Lung injury, sars-covid-2, coronavirus infection
# NCT04476940  COVID-19, Exclusive Breastfeeding, Breastfeedi...
# NCT04412265  Coronavirus, sars-covid-2, coronavirus infecti...
# NCT04427332   Coronavirus, sars-covid-2, coronavirus infection
# ...                                                        ...
# NCT04321421                       hyperimmune plasma, COVID-19
# NCT04489446  COVID19, SARS-COV2 Infection, Sildenafil, Phos...
# NCT04438993     Echocardiogram, Troponin, NT-proBNP, Cytokines
# NCT04445389
# NCT04393311
#
#                                               LocationFacility  \
# NCTId
# NCT04395924                                         Recruiting
# NCT04395482  Recruiting, Recruiting, Recruiting, Recruiting...
# NCT04476940
# NCT04412265                                         Recruiting
# NCT04427332                                         Recruiting
# ...                                                        ...
# NCT04321421
# NCT04489446
# NCT04438993                                         Recruiting
# NCT04445389                                         Recruiting
# NCT04393311
#
#                                                 LocationStatus  \
# NCTId
# NCT04395924                                         Recruiting
# NCT04395482  Recruiting', 'Recruiting', 'Recruiting', 'Recr...
# NCT04476940
# NCT04412265                                         Recruiting
# NCT04427332                                         Recruiting
# ...                                                        ...
# NCT04321421
# NCT04489446
# NCT04438993                                         Recruiting
# NCT04445389                                         Recruiting
# NCT04393311
#
#                                                   LocationCity  \
# NCTId
# NCT04395924                                            Orléans
# NCT04395482  Bergamo, Bergamo, Ferrara, Lecco, Melzo, Monza...
# NCT04476940                                          Nashville
# NCT04412265                                              Monza
# NCT04427332                                              Monza
# ...                                                        ...
# NCT04321421                                     Pavia, Mantova
# NCT04489446                                       Viña Del Mar
# NCT04438993                                            Glasgow
# NCT04445389                                              Seoul
# NCT04393311                                           Stanford
#
#                                                LocationCountry  \
# NCTId
# NCT04395924                                             France
# NCT04395482  Italy, Italy, Italy, Italy, Italy, Italy, Ital...
# NCT04476940                                      United States
# NCT04412265                                              Italy
# NCT04427332                                              Italy
# ...                                                        ...
# NCT04321421                                       Italy, Italy
# NCT04489446                                              Chile
# NCT04438993                                     United Kingdom
# NCT04445389                                 Korea, Republic of
# NCT04393311                                      United States
#
#              EnrollmentCount              StdAge  Gender
# NCTId
# NCT04395924             50.0               Adult  Female
# NCT04395482            500.0  Adult, Older Adult     All
# NCT04476940            200.0               Adult  Female
# NCT04412265            300.0  Adult, Older Adult     All
# NCT04427332            500.0  Adult, Older Adult     All
# ...                      ...                 ...     ...
# NCT04321421             49.0  Adult, Older Adult     All
# NCT04489446             40.0  Adult, Older Adult     All
# NCT04438993            100.0  Adult, Older Adult     All
# NCT04445389            210.0               Adult     All
# NCT04393311            150.0  Adult, Older Adult     All
#
# [2919 rows x 15 columns]
